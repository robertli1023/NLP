# %% [markdown]
# ## Assignments for Week-02

# %% [markdown]
# In this course, we learnt what's the search problem and what's the machine leanring. In this assignment, we need you do some more practice.

# %% [markdown]
# ### 1. Re-code the house price machine learning
#
# ###### 1. Random Choose Method to get optimal *k* and *b*
# ###### 2.Supervised Direction to get optimal *k* and *b*
# ###### 3.Gradient Descent to get optimal *k* and *b*
# ###### 4. Try different Loss function and learning rate.
#
# For example, you can change the loss function: $Loss = \frac{1}{n} sum({y_i - \hat{y_i}})^2$ to $Loss = \frac{1}{n} sum(|{y_i - \hat{y_i}}|)$
#
# And you can change the learning rate and observe the performance.

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562414412237&di=8377c38d7b50c6f8d45b92ccc78dc1e7&imgtype=0&src=http%3A%2F%2Fmmbiz.qpic.cn%2Fmmbiz_jpg%2FlSyiavfm6wPgQDuDYa42IMgSkLOcPJU91RbkMibGy7VHLrhhNVLibTYk1iaLcmXKTdHc4icTDVia59QFXwqpW8cLflaw%2F640%3Fwx_fmt%3Djpeg)

# %%
from sklearn.datasets import load_boston

# %%
data = load_boston()

# %%
X, y = data['data'], data['target']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def draw_rm_and_price():
    plt.scatter(X[:, 5], y)

# %%
draw_rm_and_price()

# %%
import random

# %%
def price(rm, k, b):
    return rm * k + b

# %%
def loss(y, y_hat): # to evaluate the performance 
    return sum((y_i - y_hat_i)**2 for y_i, y_hat_i in zip(list(y), list(y_hat))) / len(list(y))

# %% [markdown]
# ###### 1. Random Choose Method to get optimal *k* and *b*

# %%
X_rm = X[:,5]

# %%
trying_times = 2000

min_loss = float('inf')
best_k, best_b = None, None

for i in range(trying_times):
    k = random.random() * 200 - 100
    b = random.random() * 200 - 100
    price_by_random_k_and_b = [price(r, k, b) for r in X_rm]

    current_loss = loss(y, price_by_random_k_and_b)
    
    if current_loss < min_loss:
        min_loss = current_loss
        best_k, best_b = k, b
        print('When time is : {}, get best_k: {} best_b: {}, and the loss is: {}'.format(i, best_k, best_b, min_loss))
# Out:
# When time is : 0, get best_k: -8.20323054591374 best_b: -81.86496590200538, and the loss is: 24512.200662674622
# When time is : 3, get best_k: -32.418223846783604 best_b: 88.44632687423794, and the loss is: 19888.201059835133
# When time is : 5, get best_k: 13.872281695752875 best_b: -19.15509148910985, and the loss is: 2124.5448302625355
# When time is : 16, get best_k: 6.806115166823872 best_b: 4.904583114129693, and the loss is: 678.505183309741
# When time is : 21, get best_k: -0.09773352193616347 best_b: 0.07060350865005205, and the loss is: 617.8221117752221
# When time is : 31, get best_k: 8.238450673293187 best_b: -8.563671520877179, and the loss is: 471.59623348282895
# When time is : 71, get best_k: 11.257577979627612 best_b: -56.29001879133702, and the loss is: 111.063989792964
# When time is : 164, get best_k: 6.313410677286214 best_b: -11.440698260932393, and the loss is: 79.96747370206468
# When time is : 377, get best_k: 12.502601095169695 best_b: -56.93058414584509, and the loss is: 50.0882804962208

# %% [markdown]
# ###### 2.Supervised Direction to get optimal *k* and *b*

# %%
import random
trying_times = 2000

min_loss = float('inf')

best_k = random.random() * 200 - 100
best_b = random.random() * 200 - 100

direction = [
    (+1, -1),  # first element: k's change direction, second element: b's change direction
    (+1, +1), 
    (-1, -1), 
    (-1, +1),
]

next_direction = random.choice(direction)

scalar = 1

for i in range(trying_times):
    
    k_direction, b_direction = next_direction
    
    current_k, current_b = best_k + k_direction * scalar, best_b + b_direction * scalar
    
    price_by_k_and_b = [price(r, current_k, current_b) for r in X_rm]

    current_loss = loss(y, price_by_k_and_b)
    
    if current_loss < min_loss:  # performance became better
        min_loss = current_loss
        best_k, best_b = current_k, current_b
        
        next_direction = next_direction
        print('When time is : {}, get best_k: {} best_b: {}, and the loss is: {}'.format(i, best_k, best_b, min_loss))
    else:
        #print(i)
        next_direction = random.choice(direction)
# Out:
# When time is : 0, get best_k: -97.24683362783367 best_b: -64.17719727801486, and the loss is: 492639.6826232457
# When time is : 1, get best_k: -96.24683362783367 best_b: -63.17719727801486, and the loss is: 482420.978755923
# When time is : 2, get best_k: -95.24683362783367 best_b: -62.17719727801486, and the loss is: 472309.39207534736
# When time is : 3, get best_k: -94.24683362783367 best_b: -61.17719727801486, and the loss is: 462304.92258151853
# When time is : 4, get best_k: -93.24683362783367 best_b: -60.17719727801486, and the loss is: 452407.5702744375
# When time is : 5, get best_k: -92.24683362783367 best_b: -59.17719727801486, and the loss is: 442617.33515410236
# When time is : 6, get best_k: -91.24683362783367 best_b: -58.17719727801486, and the loss is: 432934.21722051536
# When time is : 7, get best_k: -90.24683362783367 best_b: -57.17719727801486, and the loss is: 423358.21647367487
# When time is : 8, get best_k: -89.24683362783367 best_b: -56.17719727801486, and the loss is: 413889.3329135819
# When time is : 9, get best_k: -88.24683362783367 best_b: -55.17719727801486, and the loss is: 404527.56654023577
# When time is : 10, get best_k: -87.24683362783367 best_b: -54.17719727801486, and the loss is: 395272.9173536359
# When time is : 11, get best_k: -86.24683362783367 best_b: -53.17719727801486, and the loss is: 386125.3853537844
# When time is : 12, get best_k: -85.24683362783367 best_b: -52.17719727801486, and the loss is: 377084.9705406791
# When time is : 13, get best_k: -84.24683362783367 best_b: -51.17719727801486, and the loss is: 368151.67291432037
# When time is : 14, get best_k: -83.24683362783367 best_b: -50.17719727801486, and the loss is: 359325.49247470935
# When time is : 15, get best_k: -82.24683362783367 best_b: -49.17719727801486, and the loss is: 350606.4292218456
# When time is : 16, get best_k: -81.24683362783367 best_b: -48.17719727801486, and the loss is: 341994.48315572843
# When time is : 17, get best_k: -80.24683362783367 best_b: -47.17719727801486, and the loss is: 333489.65427635855
# When time is : 18, get best_k: -79.24683362783367 best_b: -46.17719727801486, and the loss is: 325091.9425837357
# When time is : 19, get best_k: -78.24683362783367 best_b: -45.17719727801486, and the loss is: 316801.3480778598
# When time is : 20, get best_k: -77.24683362783367 best_b: -44.17719727801486, and the loss is: 308617.87075873057
# When time is : 21, get best_k: -76.24683362783367 best_b: -43.17719727801486, and the loss is: 300541.51062634884
# When time is : 22, get best_k: -75.24683362783367 best_b: -42.17719727801486, and the loss is: 292572.26768071385
# When time is : 23, get best_k: -74.24683362783367 best_b: -41.17719727801486, and the loss is: 284710.1419218266
# When time is : 24, get best_k: -73.24683362783367 best_b: -40.17719727801486, and the loss is: 276955.13334968564
# When time is : 25, get best_k: -72.24683362783367 best_b: -39.17719727801486, and the loss is: 269307.24196429155
# When time is : 26, get best_k: -71.24683362783367 best_b: -38.17719727801486, and the loss is: 261766.46776564504
# When time is : 27, get best_k: -70.24683362783367 best_b: -37.17719727801486, and the loss is: 254332.81075374532
# When time is : 28, get best_k: -69.24683362783367 best_b: -36.17719727801486, and the loss is: 247006.2709285929
# When time is : 29, get best_k: -68.24683362783367 best_b: -35.17719727801486, and the loss is: 239786.8482901871
# When time is : 30, get best_k: -67.24683362783367 best_b: -34.17719727801486, and the loss is: 232674.54283852867
# When time is : 31, get best_k: -66.24683362783367 best_b: -33.17719727801486, and the loss is: 225669.3545736175
# When time is : 32, get best_k: -65.24683362783367 best_b: -32.17719727801486, and the loss is: 218771.2834954524
# When time is : 33, get best_k: -64.24683362783367 best_b: -31.17719727801486, and the loss is: 211980.32960403524
# When time is : 34, get best_k: -63.24683362783367 best_b: -30.17719727801486, and the loss is: 205296.49289936482
# When time is : 35, get best_k: -62.24683362783367 best_b: -29.17719727801486, and the loss is: 198719.7733814417
# When time is : 36, get best_k: -61.24683362783367 best_b: -28.17719727801486, and the loss is: 192250.1710502654
# When time is : 37, get best_k: -60.24683362783367 best_b: -27.17719727801486, and the loss is: 185887.68590583603
# When time is : 38, get best_k: -59.24683362783367 best_b: -26.17719727801486, and the loss is: 179632.3179481538
# When time is : 39, get best_k: -58.24683362783367 best_b: -25.17719727801486, and the loss is: 173484.06717721827
# When time is : 40, get best_k: -57.24683362783367 best_b: -24.17719727801486, and the loss is: 167442.9335930303
# When time is : 41, get best_k: -56.24683362783367 best_b: -23.17719727801486, and the loss is: 161508.9171955889
# When time is : 42, get best_k: -55.24683362783367 best_b: -22.17719727801486, and the loss is: 155682.01798489512
# When time is : 43, get best_k: -54.24683362783367 best_b: -21.17719727801486, and the loss is: 149962.23596094793
# When time is : 44, get best_k: -53.24683362783367 best_b: -20.17719727801486, and the loss is: 144349.57112374762
# When time is : 45, get best_k: -52.24683362783367 best_b: -19.17719727801486, and the loss is: 138844.0234732949
# When time is : 46, get best_k: -51.24683362783367 best_b: -18.17719727801486, and the loss is: 133445.59300958907
# When time is : 47, get best_k: -50.24683362783367 best_b: -17.17719727801486, and the loss is: 128154.27973262992
# When time is : 48, get best_k: -49.24683362783367 best_b: -16.17719727801486, and the loss is: 122970.08364241816
# When time is : 49, get best_k: -48.24683362783367 best_b: -15.177197278014859, and the loss is: 117893.00473895328
# When time is : 50, get best_k: -47.24683362783367 best_b: -14.177197278014859, and the loss is: 112923.04302223542
# When time is : 51, get best_k: -46.24683362783367 best_b: -13.177197278014859, and the loss is: 108060.1984922647
# When time is : 52, get best_k: -45.24683362783367 best_b: -12.177197278014859, and the loss is: 103304.47114904087
# When time is : 53, get best_k: -44.24683362783367 best_b: -11.177197278014859, and the loss is: 98655.86099256406
# When time is : 54, get best_k: -43.24683362783367 best_b: -10.177197278014859, and the loss is: 94114.36802283446
# When time is : 55, get best_k: -42.24683362783367 best_b: -9.177197278014859, and the loss is: 89679.99223985182
# When time is : 56, get best_k: -41.24683362783367 best_b: -8.177197278014859, and the loss is: 85352.73364361632
# When time is : 57, get best_k: -40.24683362783367 best_b: -7.177197278014859, and the loss is: 81132.59223412757
# When time is : 58, get best_k: -39.24683362783367 best_b: -6.177197278014859, and the loss is: 77019.5680113861
# When time is : 59, get best_k: -38.24683362783367 best_b: -5.177197278014859, and the loss is: 73013.66097539155
# When time is : 60, get best_k: -37.24683362783367 best_b: -4.177197278014859, and the loss is: 69114.87112614405
# When time is : 61, get best_k: -36.24683362783367 best_b: -3.1771972780148587, and the loss is: 65323.19846364365
# When time is : 62, get best_k: -35.24683362783367 best_b: -2.1771972780148587, and the loss is: 61638.64298789026
# When time is : 63, get best_k: -34.24683362783367 best_b: -1.1771972780148587, and the loss is: 58061.2046988839
# When time is : 64, get best_k: -33.24683362783367 best_b: -0.17719727801485874, and the loss is: 54590.88359662463
# When time is : 65, get best_k: -32.24683362783367 best_b: 0.8228027219851413, and the loss is: 51227.6796811123
# When time is : 66, get best_k: -31.246833627833666 best_b: 1.8228027219851413, and the loss is: 47971.59295234705
# When time is : 67, get best_k: -30.246833627833666 best_b: 2.8228027219851413, and the loss is: 44822.62341032875
# When time is : 68, get best_k: -29.246833627833666 best_b: 3.8228027219851413, and the loss is: 41780.771055057616
# When time is : 69, get best_k: -28.246833627833666 best_b: 4.822802721985141, and the loss is: 38846.03588653347
# When time is : 70, get best_k: -27.246833627833666 best_b: 5.822802721985141, and the loss is: 36018.4179047563
# When time is : 71, get best_k: -26.246833627833666 best_b: 6.822802721985141, and the loss is: 33297.917109726266
# When time is : 72, get best_k: -25.246833627833666 best_b: 7.822802721985141, and the loss is: 30684.533501443228
# When time is : 73, get best_k: -24.246833627833666 best_b: 8.822802721985141, and the loss is: 28178.26707990723
# When time is : 74, get best_k: -23.246833627833666 best_b: 9.822802721985141, and the loss is: 25779.117845118264
# When time is : 75, get best_k: -22.246833627833666 best_b: 10.822802721985141, and the loss is: 23487.085797076288
# When time is : 76, get best_k: -21.246833627833666 best_b: 11.822802721985141, and the loss is: 21302.170935781392
# When time is : 77, get best_k: -20.246833627833666 best_b: 12.822802721985141, and the loss is: 19224.373261233515
# When time is : 78, get best_k: -19.246833627833666 best_b: 13.822802721985141, and the loss is: 17253.692773432722
# When time is : 79, get best_k: -18.246833627833666 best_b: 14.822802721985141, and the loss is: 15390.129472378918
# When time is : 80, get best_k: -17.246833627833666 best_b: 15.822802721985141, and the loss is: 13633.683358072143
# When time is : 81, get best_k: -16.246833627833666 best_b: 16.82280272198514, and the loss is: 11984.354430512427
# When time is : 82, get best_k: -15.246833627833666 best_b: 17.82280272198514, and the loss is: 10442.14268969974
# When time is : 83, get best_k: -14.246833627833666 best_b: 18.82280272198514, and the loss is: 9007.0481356341
# When time is : 84, get best_k: -13.246833627833666 best_b: 19.82280272198514, and the loss is: 7679.070768315469
# When time is : 85, get best_k: -12.246833627833666 best_b: 20.82280272198514, and the loss is: 6458.210587743895
# When time is : 86, get best_k: -11.246833627833666 best_b: 21.82280272198514, and the loss is: 5344.467593919333
# When time is : 87, get best_k: -10.246833627833666 best_b: 22.82280272198514, and the loss is: 4337.841786841825
# When time is : 88, get best_k: -9.246833627833666 best_b: 23.82280272198514, and the loss is: 3438.333166511351
# When time is : 89, get best_k: -8.246833627833666 best_b: 24.82280272198514, and the loss is: 2645.9417329279136
# When time is : 90, get best_k: -7.2468336278336665 best_b: 25.82280272198514, and the loss is: 1960.6674860915098
# When time is : 91, get best_k: -6.2468336278336665 best_b: 26.82280272198514, and the loss is: 1382.51042600214
# When time is : 92, get best_k: -5.2468336278336665 best_b: 27.82280272198514, and the loss is: 911.4705526598074
# When time is : 93, get best_k: -4.2468336278336665 best_b: 28.82280272198514, and the loss is: 547.5478660645106
# When time is : 94, get best_k: -3.2468336278336665 best_b: 29.82280272198514, and the loss is: 290.74236621624846
# When time is : 95, get best_k: -2.2468336278336665 best_b: 30.82280272198514, and the loss is: 141.0540531150223
# When time is : 96, get best_k: -1.2468336278336665 best_b: 31.82280272198514, and the loss is: 98.4829267608315

# %% [markdown]
# ## 2. Answer following questions:
#
#
# ###### 1. Why do we need machine learning methods instead of creating a complicated formula?

# %% [markdown]
# Ans: a complicated formula is hard to design and also not easy for maintainence, but machine learning are self adjusting and much easier for people to get a approximate accurete result.

# %% [markdown]
# ###### 2.  Wha't's the disadvantages of `the 1st Random Choosen` methods in our course?

# %% [markdown]
# Ans: this method is not time-efficient

# %% [markdown]
# ###### 3. Is the `2nd method supervised direction` better than 1st one?  What's the disadvantages of `the 2nd supversied directin` method?

# %% [markdown]
# Ans: yes, the 2nd supervised direction method did get the next right direction to reduce loss, it has only 4 direction choices and it's reduce is limited

# %% [markdown]
# ###### 4. Why do we use `Derivative / Gredient` to fit a target function?

# %% [markdown]
# Ans: see assignment 3

# %% [markdown]
# ###### 5. In the words 'Gredient Descent', what's the `Gredient` and what's the `Descent`?

# %% [markdown]
# Ans: see assignment 3

# %% [markdown]
# ###### 6. What's the advantages of `the 3rd gradient descent method` compared to the previous methods?

# %% [markdown]
# Ans:see assignment 3

# %% [markdown]
# ###### 7. Using the simple words to describe: What's the machine leanring.

# %% [markdown]
# Ans: see assignment 3

# %% [markdown]
# ## 3. Finish the search problem

# %% [markdown]
# Please using the search policy to implement an agent. This agent receives two input, one is @param start station and the other is @param destination. Your agent should give the optimal route based on Beijing Subway system.

# %% [markdown]
# > Deadline: 2019-July-13
#
# >Submit: Submit the source code and result to github.

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562414356407&di=b57814aafd215bb8b8d9d8cd37c573d6&imgtype=0&src=http%3A%2F%2Fcli.clewm.net%2Ffile%2F2015%2F03%2F24%2F174ed60082b8422ac0636cfd3efb9e7f.jpg)

# %% [markdown]
# #### Dataflow:

# %% [markdown]
# ##### 1.	Get data from web page.
#
# > a.	Get web page source from: https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485
#
# > b.	You may need @package **requests**[https://2.python-requests.org/en/master/] page to get the response via url
#
# > c.	You may need save the page source to file system.
#
# > d.	The target of this step is to get station information of all the subway lines;
#
# > e.	You may need install @package beautiful soup[https://www.crummy.com/software/BeautifulSoup/bs4/doc/]  to get the url information, or just use > Regular Expression to get the url.  Our recommendation is that using the Regular Expression and BeautiflSoup both.
#
# > f.	You may need BFS to get all the related page url from one url.
# Question: Why do we use BFS to traverse web page (or someone said, build a web spider)?  Can DFS do this job? which is better?

# %%
import requests
def check_link(url):    
    header = {"User-Agent" : "User-Agent:Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;"}
    try:              
        r = requests.get(url,headers=header).content.decode('utf8')                 
        return r  
    except:       
        print('无法链接服务器！！！')

# %%
from urllib import parse
import hashlib
 
def get_urt(address):
 
    # 以get请求为例http://api.map.baidu.com/geocoder/v2/?address=百度大厦&output=json&ak=你的ak
    queryStr = '/geocoding/v3/?address=%s&output=json&ak=NEoBOOLqOLzTfZwtzwygtqtQg3MDEFbH&callback=showLocation ' %address
  #  queryStr = '/geocoder/v2/?address=%s&output=json&ak=NEoBOOLqOLzTfZwtzwygtqtQg3MDEFbH' % address
 
    # 对queryStr进行转码，safe内的保留字符不转换
    encodedStr = parse.quote(queryStr, safe="/:=&?#+!$,;'@()*[]")
 
    # 在最后直接追加上yoursk
    rawStr = encodedStr + 'vaMit8jgmlRg24I6kBL1I1mK0zjB6Kdk'
 
    #计算sn
    sn = (hashlib.md5(parse.quote_plus(rawStr).encode("utf8")).hexdigest())
     
    #由于URL里面含有中文，所以需要用parse.quote进行处理，然后返回最终可调用的url
    url = parse.quote("http://api.map.baidu.com"+queryStr+"&sn="+sn, safe="/:=&?#+!$,;'@()*[]")   
     
    return url

# %%
url = get_urt("天安门西站")

# %%
import json
def get_location(url):
    response = json.loads(check_link(url))
    location = response['result']['location']
    return tuple([v for k, v in location.items()])

# %%
json.loads(check_link(get_urt("动物园站")))
# Out:
# {'status': 1, 'msg': 'Internal Service Error:无相关结果', 'results': []}

# %%
get_location(get_urt("亦庄站"))
# Out:
# <class 'dict'>
# (116.60819836058009, 39.819355595064636)

# %%
from bs4 import BeautifulSoup as BS
import requests
import csv
import bs4
import re

# %%
headers = {"User-Agent" : "User-Agent:Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;"}

# %%
url = "https://baike.baidu.com/item/北京地铁/408485"

# %%
html = requests.get(url, headers=headers).content.decode('utf8')

# %%
soup = BS(html)

# %%
xianlu = str(soup.find_all('table', attrs={"log-set-param":"table_view","data-sort":"sortDisabled"})[2:])

# %%
#simple_soup = str(soup.find_all('table',attrs={"log-set-param":"table_view"})[4])

# %%
what_we_want = r'href="(/item/[%\w]+)"\s+target="\_blank">(\w+线)</a>'
pattern = re.compile(what_we_want)

# %%
lines = pattern.findall(xianlu)

# %%
def remove_duplicate(line):
    l2 = []
    for i in line: 
        if not i in l2: 
            l2.append(i) 
    return l2

# %%
lines = remove_duplicate(lines)

# %%
lines
# Out:
# [('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF', '北京地铁1号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%812%E5%8F%B7%E7%BA%BF', '北京地铁2号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%814%E5%8F%B7%E7%BA%BF', '北京地铁4号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%815%E5%8F%B7%E7%BA%BF', '北京地铁5号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%816%E5%8F%B7%E7%BA%BF', '北京地铁6号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%817%E5%8F%B7%E7%BA%BF', '北京地铁7号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%819%E5%8F%B7%E7%BA%BF', '北京地铁9号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8110%E5%8F%B7%E7%BA%BF',
#   '北京地铁10号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8113%E5%8F%B7%E7%BA%BF',
#   '北京地铁13号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8114%E5%8F%B7%E7%BA%BF',
#   '北京地铁14号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8115%E5%8F%B7%E7%BA%BF',
#   '北京地铁15号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8116%E5%8F%B7%E7%BA%BF',
#   '北京地铁16号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%85%AB%E9%80%9A%E7%BA%BF',
#   '北京地铁八通线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%98%8C%E5%B9%B3%E7%BA%BF',
#   '北京地铁昌平线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E4%BA%A6%E5%BA%84%E7%BA%BF',
#   '北京地铁亦庄线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%88%BF%E5%B1%B1%E7%BA%BF',
#   '北京地铁房山线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81S1%E7%BA%BF', '北京地铁S1线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E7%87%95%E6%88%BF%E7%BA%BF',
#   '北京地铁燕房线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%818%E5%8F%B7%E7%BA%BF', '北京地铁8号线'),
#  ('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%9C%BA%E5%9C%BA%E7%BA%BF',
#   '北京地铁机场线')]

# %%
def check_link(url):    
    header = {"User-Agent" : "User-Agent:Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;"}
    try:        
        
        r = requests.get(url,headers=header).content.decode('utf8')                 
        return r  
    except:       
        print('无法链接服务器！！！')

# %%
def get_contents(ulist,rurl):   
    soup = BeautifulSoup(rurl,'lxml')  
    trs = soup.find_all('tr')    
    for tr in trs:        
        ui = []        
        for td in tr:            
            ui.append(td.string)        
            ulist.append(ui)

# %%
def get_stations(items):
    time = r"\d+:\d{2}$"
    station = r"\w+"
    pattern = re.compile(time)
    pattern1 = re.compile(station)
    
    station = []
    for item in items:
        found = 0
        if len(item) >= 5:
            #print(">5",item)
            for word in item:
                if pattern.match(str(word)):
                    found = 1
                    break
            if found == 1 and pattern1.match(str(item[0])):
                #print(item[0])
                add = str(item[0]) 
                if not str(item[0]).endswith("站"):
                    add +="站" 
                station.append(add)    
    return station

# %%
def get_stations_from_url(url):
    urlr = check_link(url)
    ulist = []
    get_contents(ulist,urlr)
    ulist = get_stations(remove_duplicate(ulist))
    return ulist

# %%
url_head = "https://baike.baidu.com"
lines_stations = {}
for url, name in lines:
    url = url_head + url
    stations = get_stations_from_url(url)
    lines_stations[name] = stations

# %%
# 亦庄线独立处理
url = "https://baike.baidu.com/item/北京地铁亦庄线"
name = "北京地铁亦庄线"
what_we_want1 = r'<a target=_blank\s+href="/item/[/%\w]+"(?:\s+\w+\-\w+="\d+")*>(\w+站)</a>'
pattern1 = re.compile(what_we_want1)
html = requests.get(url, headers=headers).content.decode('utf8')
stations = pattern1.findall(html)
stations = remove_duplicate(stations)
lines_stations[name] = stations

# %%
lines_stations
# Out:
# {'北京地铁1号线': ['苹果园站',
#   '古城站',
#   '八角游乐园站',
#   '八宝山站',
#   '玉泉路站',
#   '五棵松站',
#   '万寿路站',
#   '公主坟站',
#   '军事博物馆站',
#   '木樨地站',
#   '南礼士路站',
#   '复兴门站',
#   '西单站',
#   '天安门西站',
#   '天安门东站',
#   '王府井站',
#   '东单站',
#   '建国门站',
#   '永安里站',
#   '国贸站',
#   '大望路站',
#   '四惠站',
#   '四惠东站'],
#  '北京地铁2号线': ['西直门站',
#   '积水潭站',
#   '鼓楼大街站',
#   '安定门站',
#   '雍和宫站',
#   '东直门站',
#   '东四十条站',
#   '朝阳门站',
#   '建国门站',
#   '北京站',
#   '崇文门站',
#   '前门站',
#   '和平门站',
#   '宣武门站',
#   '长椿街站',
#   '复兴门站',
#   '阜成门站',
#   '车公庄站'],
#  '北京地铁4号线': ['安河桥北站',
#   '北宫门站',
#   '西苑站',
#   '圆明园站',
#   '北京大学东门站',
#   '中关村站',
#   '海淀黄庄站',
#   '人民大学站',
#   '魏公村站',
#   '国家图书馆站',
#   '动物园站',
#   '西直门站',
#   '新街口站',
#   '平安里站',
#   '西四站',
#   '灵境胡同站',
#   '西单站',
#   '宣武门站',
#   '菜市口站',
#   '陶然亭站',
#   '北京南站',
#   '马家堡站',
#   '角门西站',
#   '公益西桥站'],
#  '北京地铁5号线': ['宋家庄站',
#   '刘家窑站',
#   '蒲黄榆站',
#   '天坛东门站',
#   '磁器口站',
#   '崇文门站',
#   '东单站',
#   '灯市口站',
#   '东四站',
#   '张自忠路站',
#   '北新桥站',
#   '雍和宫站',
#   '和平里北街站',
#   '和平西桥站',
#   '惠新西街南口站',
#   '惠新西街北口站',
#   '大屯路东站',
#   '北苑路北站',
#   '立水桥南站',
#   '立水桥站',
#   '天通苑南站',
#   '天通苑站',
#   '天通苑北站'],
#  '北京地铁6号线': ['金安桥站',
#   '杨庄站',
#   '西黄村站',
#   '廖公庄站',
#   '田村站',
#   '海淀五路居站',
#   '慈寿寺站',
#   '花园桥站',
#   '白石桥南站',
#   '车公庄西站',
#   '车公庄站',
#   '平安里站',
#   '北海北站',
#   '南锣鼓巷站',
#   '东四站',
#   '朝阳门站',
#   '东大桥站',
#   '呼家楼站',
#   '金台路站',
#   '十里堡站',
#   '青年路站',
#   '褡裢坡站',
#   '黄渠站',
#   '常营站',
#   '草房站',
#   '物资学院路站',
#   '通州北关站',
#   '北运河西站',
#   '北运河东站',
#   '郝家府站',
#   '东夏园站',
#   '潞城站'],
#  '北京地铁7号线': ['北京西站',
#   '湾子站',
#   '达官营站',
#   '广安门内站',
#   '菜市口站',
#   '虎坊桥站',
#   '珠市口站',
#   '桥湾站',
#   '磁器口站',
#   '广渠门内站',
#   '广渠门外站',
#   '九龙山站',
#   '大郊亭站',
#   '百子湾站',
#   '化工站',
#   '南楼梓庄站',
#   '欢乐谷景区站',
#   '双合站',
#   '焦化厂站'],
#  '北京地铁9号线': ['郭公庄站',
#   '丰台科技园站',
#   '科怡路站',
#   '丰台南路站',
#   '丰台东大街站',
#   '七里庄站',
#   '六里桥站',
#   '六里桥东站',
#   '北京西站',
#   '军事博物馆站',
#   '白堆子站',
#   '白石桥南站',
#   '国家图书馆站'],
#  '北京地铁10号线': ['巴沟站',
#   '苏州街站',
#   '海淀黄庄站',
#   '知春里站',
#   '知春路站',
#   '西土城站',
#   '牡丹园站',
#   '健德门站',
#   '北土城站',
#   '安贞门站',
#   '惠新西街南口站',
#   '芍药居站',
#   '太阳宫站',
#   '三元桥站',
#   '亮马桥站',
#   '农业展览馆站',
#   '团结湖站',
#   '呼家楼站',
#   '金台夕照站',
#   '国贸站',
#   '双井站',
#   '劲松站',
#   '潘家园站',
#   '十里河站',
#   '分钟寺站',
#   '成寿寺站',
#   '宋家庄站',
#   '石榴庄站',
#   '大红门站',
#   '角门东站',
#   '角门西站',
#   '草桥站',
#   '纪家庙站',
#   '首经贸站',
#   '丰台站',
#   '泥洼站',
#   '西局站',
#   '六里桥站',
#   '莲花桥站',
#   '公主坟站',
#   '西钓鱼台站',
#   '慈寿寺站',
#   '车道沟站',
#   '长春桥站',
#   '火器营站'],
#  '北京地铁13号线': ['西直门站',
#   '大钟寺站',
#   '知春路站',
#   '五道口站',
#   '上地站',
#   '西二旗站',
#   '龙泽站',
#   '回龙观站',
#   '霍营站',
#   '立水桥站',
#   '北苑站',
#   '望京西站',
#   '芍药居站',
#   '光熙门站',
#   '柳芳站',
#   '东直门站'],
#  '北京地铁14号线': ['张郭庄站',
#   '园博园站',
#   '大瓦窑站',
#   '郭庄子站',
#   '大井站',
#   '七里庄站',
#   '西局站',
#   '北京南站',
#   '永定门外站',
#   '景泰站',
#   '蒲黄榆站',
#   '方庄站',
#   '十里河站',
#   '北工大西门站',
#   '九龙山站',
#   '大望路站',
#   '金台路站',
#   '朝阳公园站',
#   '枣营站',
#   '东风北桥站',
#   '将台站',
#   '望京南站',
#   '阜通站',
#   '望京站',
#   '东湖渠站',
#   '来广营站',
#   '善各庄站'],
#  '北京地铁15号线': ['俸伯站',
#   '顺义站',
#   '石门站',
#   '南法信站',
#   '后沙峪站',
#   '花梨坎站',
#   '国展站',
#   '孙河站',
#   '马泉营站',
#   '崔各庄站',
#   '望京东站',
#   '望京站',
#   '望京西站',
#   '关庄站',
#   '大屯路东站',
#   '安立路站',
#   '奥林匹克公园站',
#   '北沙滩站',
#   '六道口站',
#   '清华东路西口站'],
#  '北京地铁16号线': ['西苑站',
#   '农大南路站',
#   '马连洼站',
#   '西北旺站',
#   '永丰南站',
#   '永丰站',
#   '屯佃站',
#   '稻香湖路站',
#   '温阳路站',
#   '北安河站'],
#  '北京地铁八通线': ['四惠站',
#   '四惠东站',
#   '高碑店站',
#   '传媒大学站',
#   '双桥站',
#   '管庄站',
#   '八里桥站',
#   '通州北苑站',
#   '果园站',
#   '九棵树站',
#   '梨园站',
#   '临河里站',
#   '土桥站'],
#  '北京地铁昌平线': ['昌平西山口站',
#   '十三陵景区站',
#   '昌平站',
#   '昌平东关站',
#   '北邵洼站',
#   '南邵站',
#   '沙河高教园站',
#   '沙河站',
#   '巩华城站',
#   '朱辛庄站',
#   '生命科学园站',
#   '西二旗站'],
#  '北京地铁亦庄线': ['亦庄火车站',
#   '宋家庄站',
#   '车站',
#   '肖村站',
#   '小红门站',
#   '旧宫站',
#   '亦庄桥站',
#   '亦庄文化园站',
#   '万源街站',
#   '荣京东街站',
#   '荣昌东街站',
#   '同济南路站',
#   '经海路站',
#   '次渠南站',
#   '次渠站'],
#  '北京地铁房山线': ['郭公庄站',
#   '大葆台站',
#   '稻田站',
#   '长阳站',
#   '篱笆房站',
#   '广阳城站',
#   '良乡大学城北站',
#   '良乡大学城站',
#   '良乡大学城西站',
#   '良乡南关站',
#   '苏庄站',
#   '阎村东站'],
#  '北京地铁S1线': ['金安桥站', '四道桥站', '桥户营站', '上岸站', '栗园庄站', '小园站', '石厂站'],
#  '北京地铁燕房线': ['燕山站',
#   '房山城关站',
#   '饶乐府站',
#   '马各庄站',
#   '大石河东站',
#   '星城站',
#   '阎村站',
#   '紫草坞站',
#   '阎村东站'],
#  '北京地铁8号线': ['朱辛庄站',
#   '育知路站',
#   '平西府站',
#   '回龙观东大街站',
#   '霍营站',
#   '育新站',
#   '西小口站',
#   '永泰庄站',
#   '林萃桥站',
#   '森林公园南门站',
#   '奥林匹克公园站',
#   '奥体中心站',
#   '北土城站',
#   '安华桥站',
#   '安德里北街站',
#   '鼓楼大街站',
#   '什刹海站',
#   '南锣鼓巷站',
#   '中国美术馆站',
#   '瀛海站',
#   '德茂站',
#   '五福堂站',
#   '火箭万源站',
#   '东高地站',
#   '和义站',
#   '大红门南站',
#   '海户屯站',
#   '木樨园站',
#   '永定门外站',
#   '天桥站',
#   '珠市口站'],
#  '北京地铁机场线': ['东直门站', '三元桥站', '3号航站楼站', '2号航站楼站']}

# %% [markdown]
# ##### 2.	Preprocessing data from page source.
#
# > a.	Based on the page source gotten from url. You may need some more preprocessing of the page.
#
# > b.	the Regular Expression you may need to process the text information.
#
# > c.	You may need @package networkx, @package matplotlib to visualize data.
#
# > d.	You should build a dictionary or graph which could represent the connection information of Beijing subway routes.
#
# > e.	You may need the defaultdict, set data structures to implement this procedure.

# %%
station_lines = {}
for line, stations in lines_stations.items():
    for station in stations:
        if station in station_lines:
            station_lines[station] += [line]
        else:
            station_lines[station] = [line]

# %%
len(station_lines)
# Out:
# 312

# %%
station_lines
# Out:
# {'苹果园站': ['北京地铁1号线'],
#  '古城站': ['北京地铁1号线'],
#  '八角游乐园站': ['北京地铁1号线'],
#  '八宝山站': ['北京地铁1号线'],
#  '玉泉路站': ['北京地铁1号线'],
#  '五棵松站': ['北京地铁1号线'],
#  '万寿路站': ['北京地铁1号线'],
#  '公主坟站': ['北京地铁1号线', '北京地铁10号线'],
#  '军事博物馆站': ['北京地铁1号线', '北京地铁9号线'],
#  '木樨地站': ['北京地铁1号线'],
#  '南礼士路站': ['北京地铁1号线'],
#  '复兴门站': ['北京地铁1号线', '北京地铁2号线'],
#  '西单站': ['北京地铁1号线', '北京地铁4号线'],
#  '天安门西站': ['北京地铁1号线'],
#  '天安门东站': ['北京地铁1号线'],
#  '王府井站': ['北京地铁1号线'],
#  '东单站': ['北京地铁1号线', '北京地铁5号线'],
#  '建国门站': ['北京地铁1号线', '北京地铁2号线'],
#  '永安里站': ['北京地铁1号线'],
#  '国贸站': ['北京地铁1号线', '北京地铁10号线'],
#  '大望路站': ['北京地铁1号线', '北京地铁14号线'],
#  '四惠站': ['北京地铁1号线', '北京地铁八通线'],
#  '四惠东站': ['北京地铁1号线', '北京地铁八通线'],
#  '西直门站': ['北京地铁2号线', '北京地铁4号线', '北京地铁13号线'],
#  '积水潭站': ['北京地铁2号线'],
#  '鼓楼大街站': ['北京地铁2号线', '北京地铁8号线'],
#  '安定门站': ['北京地铁2号线'],
#  '雍和宫站': ['北京地铁2号线', '北京地铁5号线'],
#  '东直门站': ['北京地铁2号线', '北京地铁13号线', '北京地铁机场线'],
#  '东四十条站': ['北京地铁2号线'],
#  '朝阳门站': ['北京地铁2号线', '北京地铁6号线'],
#  '北京站': ['北京地铁2号线'],
#  '崇文门站': ['北京地铁2号线', '北京地铁5号线'],
#  '前门站': ['北京地铁2号线'],
#  '和平门站': ['北京地铁2号线'],
#  '宣武门站': ['北京地铁2号线', '北京地铁4号线'],
#  '长椿街站': ['北京地铁2号线'],
#  '阜成门站': ['北京地铁2号线'],
#  '车公庄站': ['北京地铁2号线', '北京地铁6号线'],
#  '安河桥北站': ['北京地铁4号线'],
#  '北宫门站': ['北京地铁4号线'],
#  '西苑站': ['北京地铁4号线', '北京地铁16号线'],
#  '圆明园站': ['北京地铁4号线'],
#  '北京大学东门站': ['北京地铁4号线'],
#  '中关村站': ['北京地铁4号线'],
#  '海淀黄庄站': ['北京地铁4号线', '北京地铁10号线'],
#  '人民大学站': ['北京地铁4号线'],
#  '魏公村站': ['北京地铁4号线'],
#  '国家图书馆站': ['北京地铁4号线', '北京地铁9号线'],
#  '动物园站': ['北京地铁4号线'],
#  '新街口站': ['北京地铁4号线'],
#  '平安里站': ['北京地铁4号线', '北京地铁6号线'],
#  '西四站': ['北京地铁4号线'],
#  '灵境胡同站': ['北京地铁4号线'],
#  '菜市口站': ['北京地铁4号线', '北京地铁7号线'],
#  '陶然亭站': ['北京地铁4号线'],
#  '北京南站': ['北京地铁4号线', '北京地铁14号线'],
#  '马家堡站': ['北京地铁4号线'],
#  '角门西站': ['北京地铁4号线', '北京地铁10号线'],
#  '公益西桥站': ['北京地铁4号线'],
#  '宋家庄站': ['北京地铁5号线', '北京地铁10号线', '北京地铁亦庄线'],
#  '刘家窑站': ['北京地铁5号线'],
#  '蒲黄榆站': ['北京地铁5号线', '北京地铁14号线'],
#  '天坛东门站': ['北京地铁5号线'],
#  '磁器口站': ['北京地铁5号线', '北京地铁7号线'],
#  '灯市口站': ['北京地铁5号线'],
#  '东四站': ['北京地铁5号线', '北京地铁6号线'],
#  '张自忠路站': ['北京地铁5号线'],
#  '北新桥站': ['北京地铁5号线'],
#  '和平里北街站': ['北京地铁5号线'],
#  '和平西桥站': ['北京地铁5号线'],
#  '惠新西街南口站': ['北京地铁5号线', '北京地铁10号线'],
#  '惠新西街北口站': ['北京地铁5号线'],
#  '大屯路东站': ['北京地铁5号线', '北京地铁15号线'],
#  '北苑路北站': ['北京地铁5号线'],
#  '立水桥南站': ['北京地铁5号线'],
#  '立水桥站': ['北京地铁5号线', '北京地铁13号线'],
#  '天通苑南站': ['北京地铁5号线'],
#  '天通苑站': ['北京地铁5号线'],
#  '天通苑北站': ['北京地铁5号线'],
#  '金安桥站': ['北京地铁6号线', '北京地铁S1线'],
#  '杨庄站': ['北京地铁6号线'],
#  '西黄村站': ['北京地铁6号线'],
#  '廖公庄站': ['北京地铁6号线'],
#  '田村站': ['北京地铁6号线'],
#  '海淀五路居站': ['北京地铁6号线'],
#  '慈寿寺站': ['北京地铁6号线', '北京地铁10号线'],
#  '花园桥站': ['北京地铁6号线'],
#  '白石桥南站': ['北京地铁6号线', '北京地铁9号线'],
#  '车公庄西站': ['北京地铁6号线'],
#  '北海北站': ['北京地铁6号线'],
#  '南锣鼓巷站': ['北京地铁6号线', '北京地铁8号线'],
#  '东大桥站': ['北京地铁6号线'],
#  '呼家楼站': ['北京地铁6号线', '北京地铁10号线'],
#  '金台路站': ['北京地铁6号线', '北京地铁14号线'],
#  '十里堡站': ['北京地铁6号线'],
#  '青年路站': ['北京地铁6号线'],
#  '褡裢坡站': ['北京地铁6号线'],
#  '黄渠站': ['北京地铁6号线'],
#  '常营站': ['北京地铁6号线'],
#  '草房站': ['北京地铁6号线'],
#  '物资学院路站': ['北京地铁6号线'],
#  '通州北关站': ['北京地铁6号线'],
#  '北运河西站': ['北京地铁6号线'],
#  '北运河东站': ['北京地铁6号线'],
#  '郝家府站': ['北京地铁6号线'],
#  '东夏园站': ['北京地铁6号线'],
#  '潞城站': ['北京地铁6号线'],
#  '北京西站': ['北京地铁7号线', '北京地铁9号线'],
#  '湾子站': ['北京地铁7号线'],
#  '达官营站': ['北京地铁7号线'],
#  '广安门内站': ['北京地铁7号线'],
#  '虎坊桥站': ['北京地铁7号线'],
#  '珠市口站': ['北京地铁7号线', '北京地铁8号线'],
#  '桥湾站': ['北京地铁7号线'],
#  '广渠门内站': ['北京地铁7号线'],
#  '广渠门外站': ['北京地铁7号线'],
#  '九龙山站': ['北京地铁7号线', '北京地铁14号线'],
#  '大郊亭站': ['北京地铁7号线'],
#  '百子湾站': ['北京地铁7号线'],
#  '化工站': ['北京地铁7号线'],
#  '南楼梓庄站': ['北京地铁7号线'],
#  '欢乐谷景区站': ['北京地铁7号线'],
#  '双合站': ['北京地铁7号线'],
#  '焦化厂站': ['北京地铁7号线'],
#  '郭公庄站': ['北京地铁9号线', '北京地铁房山线'],
#  '丰台科技园站': ['北京地铁9号线'],
#  '科怡路站': ['北京地铁9号线'],
#  '丰台南路站': ['北京地铁9号线'],
#  '丰台东大街站': ['北京地铁9号线'],
#  '七里庄站': ['北京地铁9号线', '北京地铁14号线'],
#  '六里桥站': ['北京地铁9号线', '北京地铁10号线'],
#  '六里桥东站': ['北京地铁9号线'],
#  '白堆子站': ['北京地铁9号线'],
#  '巴沟站': ['北京地铁10号线'],
#  '苏州街站': ['北京地铁10号线'],
#  '知春里站': ['北京地铁10号线'],
#  '知春路站': ['北京地铁10号线', '北京地铁13号线'],
#  '西土城站': ['北京地铁10号线'],
#  '牡丹园站': ['北京地铁10号线'],
#  '健德门站': ['北京地铁10号线'],
#  '北土城站': ['北京地铁10号线', '北京地铁8号线'],
#  '安贞门站': ['北京地铁10号线'],
#  '芍药居站': ['北京地铁10号线', '北京地铁13号线'],
#  '太阳宫站': ['北京地铁10号线'],
#  '三元桥站': ['北京地铁10号线', '北京地铁机场线'],
#  '亮马桥站': ['北京地铁10号线'],
#  '农业展览馆站': ['北京地铁10号线'],
#  '团结湖站': ['北京地铁10号线'],
#  '金台夕照站': ['北京地铁10号线'],
#  '双井站': ['北京地铁10号线'],
#  '劲松站': ['北京地铁10号线'],
#  '潘家园站': ['北京地铁10号线'],
#  '十里河站': ['北京地铁10号线', '北京地铁14号线'],
#  '分钟寺站': ['北京地铁10号线'],
#  '成寿寺站': ['北京地铁10号线'],
#  '石榴庄站': ['北京地铁10号线'],
#  '大红门站': ['北京地铁10号线'],
#  '角门东站': ['北京地铁10号线'],
#  '草桥站': ['北京地铁10号线'],
#  '纪家庙站': ['北京地铁10号线'],
#  '首经贸站': ['北京地铁10号线'],
#  '丰台站': ['北京地铁10号线'],
#  '泥洼站': ['北京地铁10号线'],
#  '西局站': ['北京地铁10号线', '北京地铁14号线'],
#  '莲花桥站': ['北京地铁10号线'],
#  '西钓鱼台站': ['北京地铁10号线'],
#  '车道沟站': ['北京地铁10号线'],
#  '长春桥站': ['北京地铁10号线'],
#  '火器营站': ['北京地铁10号线'],
#  '大钟寺站': ['北京地铁13号线'],
#  '五道口站': ['北京地铁13号线'],
#  '上地站': ['北京地铁13号线'],
#  '西二旗站': ['北京地铁13号线', '北京地铁昌平线'],
#  '龙泽站': ['北京地铁13号线'],
#  '回龙观站': ['北京地铁13号线'],
#  '霍营站': ['北京地铁13号线', '北京地铁8号线'],
#  '北苑站': ['北京地铁13号线'],
#  '望京西站': ['北京地铁13号线', '北京地铁15号线'],
#  '光熙门站': ['北京地铁13号线'],
#  '柳芳站': ['北京地铁13号线'],
#  '张郭庄站': ['北京地铁14号线'],
#  '园博园站': ['北京地铁14号线'],
#  '大瓦窑站': ['北京地铁14号线'],
#  '郭庄子站': ['北京地铁14号线'],
#  '大井站': ['北京地铁14号线'],
#  '永定门外站': ['北京地铁14号线', '北京地铁8号线'],
#  '景泰站': ['北京地铁14号线'],
#  '方庄站': ['北京地铁14号线'],
#  '北工大西门站': ['北京地铁14号线'],
#  '朝阳公园站': ['北京地铁14号线'],
#  '枣营站': ['北京地铁14号线'],
#  '东风北桥站': ['北京地铁14号线'],
#  '将台站': ['北京地铁14号线'],
#  '望京南站': ['北京地铁14号线'],
#  '阜通站': ['北京地铁14号线'],
#  '望京站': ['北京地铁14号线', '北京地铁15号线'],
#  '东湖渠站': ['北京地铁14号线'],
#  '来广营站': ['北京地铁14号线'],
#  '善各庄站': ['北京地铁14号线'],
#  '俸伯站': ['北京地铁15号线'],
#  '顺义站': ['北京地铁15号线'],
#  '石门站': ['北京地铁15号线'],
#  '南法信站': ['北京地铁15号线'],
#  '后沙峪站': ['北京地铁15号线'],
#  '花梨坎站': ['北京地铁15号线'],
#  '国展站': ['北京地铁15号线'],
#  '孙河站': ['北京地铁15号线'],
#  '马泉营站': ['北京地铁15号线'],
#  '崔各庄站': ['北京地铁15号线'],
#  '望京东站': ['北京地铁15号线'],
#  '关庄站': ['北京地铁15号线'],
#  '安立路站': ['北京地铁15号线'],
#  '奥林匹克公园站': ['北京地铁15号线', '北京地铁8号线'],
#  '北沙滩站': ['北京地铁15号线'],
#  '六道口站': ['北京地铁15号线'],
#  '清华东路西口站': ['北京地铁15号线'],
#  '农大南路站': ['北京地铁16号线'],
#  '马连洼站': ['北京地铁16号线'],
#  '西北旺站': ['北京地铁16号线'],
#  '永丰南站': ['北京地铁16号线'],
#  '永丰站': ['北京地铁16号线'],
#  '屯佃站': ['北京地铁16号线'],
#  '稻香湖路站': ['北京地铁16号线'],
#  '温阳路站': ['北京地铁16号线'],
#  '北安河站': ['北京地铁16号线'],
#  '高碑店站': ['北京地铁八通线'],
#  '传媒大学站': ['北京地铁八通线'],
#  '双桥站': ['北京地铁八通线'],
#  '管庄站': ['北京地铁八通线'],
#  '八里桥站': ['北京地铁八通线'],
#  '通州北苑站': ['北京地铁八通线'],
#  '果园站': ['北京地铁八通线'],
#  '九棵树站': ['北京地铁八通线'],
#  '梨园站': ['北京地铁八通线'],
#  '临河里站': ['北京地铁八通线'],
#  '土桥站': ['北京地铁八通线'],
#  '昌平西山口站': ['北京地铁昌平线'],
#  '十三陵景区站': ['北京地铁昌平线'],
#  '昌平站': ['北京地铁昌平线'],
#  '昌平东关站': ['北京地铁昌平线'],
#  '北邵洼站': ['北京地铁昌平线'],
#  '南邵站': ['北京地铁昌平线'],
#  '沙河高教园站': ['北京地铁昌平线'],
#  '沙河站': ['北京地铁昌平线'],
#  '巩华城站': ['北京地铁昌平线'],
#  '朱辛庄站': ['北京地铁昌平线', '北京地铁8号线'],
#  '生命科学园站': ['北京地铁昌平线'],
#  '亦庄火车站': ['北京地铁亦庄线'],
#  '车站': ['北京地铁亦庄线'],
#  '肖村站': ['北京地铁亦庄线'],
#  '小红门站': ['北京地铁亦庄线'],
#  '旧宫站': ['北京地铁亦庄线'],
#  '亦庄桥站': ['北京地铁亦庄线'],
#  '亦庄文化园站': ['北京地铁亦庄线'],
#  '万源街站': ['北京地铁亦庄线'],
#  '荣京东街站': ['北京地铁亦庄线'],
#  '荣昌东街站': ['北京地铁亦庄线'],
#  '同济南路站': ['北京地铁亦庄线'],
#  '经海路站': ['北京地铁亦庄线'],
#  '次渠南站': ['北京地铁亦庄线'],
#  '次渠站': ['北京地铁亦庄线'],
#  '大葆台站': ['北京地铁房山线'],
#  '稻田站': ['北京地铁房山线'],
#  '长阳站': ['北京地铁房山线'],
#  '篱笆房站': ['北京地铁房山线'],
#  '广阳城站': ['北京地铁房山线'],
#  '良乡大学城北站': ['北京地铁房山线'],
#  '良乡大学城站': ['北京地铁房山线'],
#  '良乡大学城西站': ['北京地铁房山线'],
#  '良乡南关站': ['北京地铁房山线'],
#  '苏庄站': ['北京地铁房山线'],
#  '阎村东站': ['北京地铁房山线', '北京地铁燕房线'],
#  '四道桥站': ['北京地铁S1线'],
#  '桥户营站': ['北京地铁S1线'],
#  '上岸站': ['北京地铁S1线'],
#  '栗园庄站': ['北京地铁S1线'],
#  '小园站': ['北京地铁S1线'],
#  '石厂站': ['北京地铁S1线'],
#  '燕山站': ['北京地铁燕房线'],
#  '房山城关站': ['北京地铁燕房线'],
#  '饶乐府站': ['北京地铁燕房线'],
#  '马各庄站': ['北京地铁燕房线'],
#  '大石河东站': ['北京地铁燕房线'],
#  '星城站': ['北京地铁燕房线'],
#  '阎村站': ['北京地铁燕房线'],
#  '紫草坞站': ['北京地铁燕房线'],
#  '育知路站': ['北京地铁8号线'],
#  '平西府站': ['北京地铁8号线'],
#  '回龙观东大街站': ['北京地铁8号线'],
#  '育新站': ['北京地铁8号线'],
#  '西小口站': ['北京地铁8号线'],
#  '永泰庄站': ['北京地铁8号线'],
#  '林萃桥站': ['北京地铁8号线'],
#  '森林公园南门站': ['北京地铁8号线'],
#  '奥体中心站': ['北京地铁8号线'],
#  '安华桥站': ['北京地铁8号线'],
#  '安德里北街站': ['北京地铁8号线'],
#  '什刹海站': ['北京地铁8号线'],
#  '中国美术馆站': ['北京地铁8号线'],
#  '瀛海站': ['北京地铁8号线'],
#  '德茂站': ['北京地铁8号线'],
#  '五福堂站': ['北京地铁8号线'],
#  '火箭万源站': ['北京地铁8号线'],
#  '东高地站': ['北京地铁8号线'],
#  '和义站': ['北京地铁8号线'],
#  '大红门南站': ['北京地铁8号线'],
#  '海户屯站': ['北京地铁8号线'],
#  '木樨园站': ['北京地铁8号线'],
#  '天桥站': ['北京地铁8号线'],
#  '3号航站楼站': ['北京地铁机场线'],
#  '2号航站楼站': ['北京地铁机场线']}

# %%
station_location={}
for k, v in station_lines.items():
    try:
        location = get_location(get_urt(k))
    except:
        print(k)
    else:
        station_location[k] = location
# Out:
# 动物园站
# 分钟寺站
# 首经贸站
# 泥洼站
# 西钓鱼台站
# 将台站
# 阜通站
# 星城站

# %%
rest = {'动物园站':(116.345204,39.943923),'分钟寺站':(116.460348,39.857886),'首经贸站':(116.326613,39.85032),\
        '泥洼站':(116.310813,39.8647),'西钓鱼台站':(116.304186,39.929671),'将台站':(116.496253,39.97696),\
        '阜通站':(116.477642,39.997887),'星城站':(116.067772,39.719734)}
for k, v in rest.items():
    station_location[k] = v

# %%
station_location['动物园站']
# Out:
# (116.345204, 39.943923)

# %%
import networkx as nx
stations = list(station_location.keys())
station_graph = nx.Graph()
station_graph.add_nodes_from(stations)

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(station_graph, station_location, with_labels=True, node_size=2)

# %% [markdown]
# 直接爬虫发现地图画出来有些问题，再换一种方法试试

# %%
import numpy as np
import math
#百度经纬坐标转换
PI = math.pi

def _transformlat(coordinates):
    lng = coordinates[ : , 0] - 105
    lat = coordinates[ : , 1] - 35
    ret = -100 + 2 * lng + 3 * lat + 0.2 * lat * lat + \
          0.1 * lng * lat + 0.2 * np.sqrt(np.fabs(lng))
    ret += (20 * np.sin(6 * lng * PI) + 20 *
            np.sin(2 * lng * PI)) * 2 / 3
    ret += (20 * np.sin(lat * PI) + 40 *
            np.sin(lat / 3 * PI)) * 2 / 3
    ret += (160 * np.sin(lat / 12 * PI) + 320 *
            np.sin(lat * PI / 30.0)) * 2 / 3
    return ret


def _transformlng(coordinates):
    lng = coordinates[ : , 0] - 105
    lat = coordinates[ : , 1] - 35
    ret = 300 + lng + 2 * lat + 0.1 * lng * lng + \
          0.1 * lng * lat + 0.1 * np.sqrt(np.fabs(lng))
    ret += (20 * np.sin(6 * lng * PI) + 20 *
            np.sin(2 * lng * PI)) * 2 / 3
    ret += (20 * np.sin(lng * PI) + 40 *
            np.sin(lng / 3 * PI)) * 2 / 3
    ret += (150 * np.sin(lng / 12 * PI) + 300 *
            np.sin(lng / 30 * PI)) * 2 / 3
    return ret


def gcj02_to_wgs84(coordinates):
    """
    GCJ-02转WGS-84
    :param coordinates: GCJ-02坐标系的经度和纬度的numpy数组
    :returns: WGS-84坐标系的经度和纬度的numpy数组
    """
    ee = 0.006693421622965943  # 偏心率平方
    a = 6378245  # 长半轴
    lng = coordinates[ : , 0]
    lat = coordinates[ : , 1]
    is_in_china= (lng > 73.66) & (lng < 135.05) & (lat > 3.86) & (lat < 53.55)
    _transform = coordinates[is_in_china]  #只对国内的坐标做偏移
    
    dlat = _transformlat(_transform)
    dlng = _transformlng(_transform)
    radlat = _transform[ : , 1] / 180 * PI
    magic = np.sin(radlat)
    magic = 1 - ee * magic * magic
    sqrtmagic = np.sqrt(magic)
    dlat = (dlat * 180.0) / ((a * (1 - ee)) / (magic * sqrtmagic) * PI)
    dlng = (dlng * 180.0) / (a / sqrtmagic * np.cos(radlat) * PI)
    mglat = _transform[ : , 1] + dlat
    mglng = _transform[ : , 0] + dlng
    coordinates[is_in_china] = np.array([
        _transform[ : , 0] * 2 - mglng, _transform[ : , 1] * 2 - mglat
    ]).T
    return coordinates


def bd09_to_gcj02(coordinates):
    """
    BD-09转GCJ-02
    :param coordinates: BD-09坐标系的经度和纬度的numpy数组
    :returns: GCJ-02坐标系的经度和纬度的numpy数组
    """
    x_pi = PI * 3000 / 180
    x = coordinates[ : , 0] - 0.0065
    y = coordinates[ : , 1] - 0.006
    z = np.sqrt(x * x + y * y) - 0.00002 * np.sin(y * x_pi)
    theta = np.arctan2(y, x) - 0.000003 * np.cos(x * x_pi)
    lng = z * np.cos(theta)
    lat = z * np.sin(theta)
    coordinates = np.array([lng, lat]).T
    return coordinates


def bd09_to_wgs84(coordinates):
    """
    BD-09转WGS-84
    :param coordinates: BD-09坐标系的经度和纬度的numpy数组
    :returns: WGS-84坐标系的经度和纬度的numpy数组
    """
    return gcj02_to_wgs84(bd09_to_gcj02(coordinates))


def mercator_to_bd09(mercator):
    """
    BD-09MC转BD-09
    :param coordinates: GCJ-02坐标系的经度和纬度的numpy数组
    :returns: WGS-84坐标系的经度和纬度的numpy数组
    """
    MCBAND = [12890594.86, 8362377.87, 5591021, 3481989.83, 1678043.12, 0]
    MC2LL = [[1.410526172116255e-08,   8.98305509648872e-06,    -1.9939833816331,        
              200.9824383106796,       -187.2403703815547,      91.6087516669843,
              -23.38765649603339,      2.57121317296198,        -0.03801003308653,
              17337981.2],
            [-7.435856389565537e-09,  8.983055097726239e-06,   -0.78625201886289,
             96.32687599759846,       -1.85204757529826,       -59.36935905485877,
             47.40033549296737,       -16.50741931063887,      2.28786674699375,
             10260144.86],
            [-3.030883460898826e-08,  8.98305509983578e-06,    0.30071316287616,
             59.74293618442277,       7.357984074871,          -25.38371002664745,
             13.45380521110908,       -3.29883767235584,       0.32710905363475,
             6856817.37],
            [-1.981981304930552e-08,  8.983055099779535e-06,   0.03278182852591,
             40.31678527705744,       0.65659298677277,        -4.44255534477492,
             0.85341911805263,        0.12923347998204,        -0.04625736007561,
             4482777.06], 
            [3.09191371068437e-09,    8.983055096812155e-06,   6.995724062e-05,
             23.10934304144901,       -0.00023663490511,       -0.6321817810242,
             -0.00663494467273,       0.03430082397953,        -0.00466043876332,
             2555164.4],  
            [2.890871144776878e-09,   8.983055095805407e-06,   -3.068298e-08,
             7.47137025468032,        -3.53937994e-06,         -0.02145144861037,
             -1.234426596e-05,        0.00010322952773,        -3.23890364e-06,
             826088.5]] 
    
    x = np.abs(mercator[ : , 0])
    y = np.abs(mercator[ : , 1])
    coef = np.array([
           MC2LL[index] for index in 
           (np.tile(y.reshape((-1, 1)), (1, 6)) < MCBAND).sum(axis=1)
    ])   
    return converter(x, y, coef)


def converter(x, y, coef):
    x_temp = coef[ : ,0] + coef[ : ,1] * np.abs(x)
    x_n = np.abs(y) / coef[ : ,9]
    y_temp = coef[ : ,2] + coef[ : ,3] * x_n + coef[ : ,4] * x_n ** 2 + \
             coef[ : ,5] * x_n ** 3 + coef[ : ,6] * x_n ** 4 + coef[ : ,7] * x_n ** 5 + \
             coef[ : ,8] * x_n ** 6
    x[x < 0] = -1
    x[x >= 0] = 1
    y[y < 0] = -1
    y[y >= 0] = 1    
    x_temp *= x
    y_temp *= y
    coordinates = np.array([x_temp, y_temp]).T
    return coordinates

# %%
import requests
import time

null = None #将json中的null定义为None
city_code = 131 #北京的城市编号
station_info = requests.get('http://map.baidu.com/?qt=bsi&c=%s&t=%s' % (
                    city_code, 
                    int(time.time() * 1000)
               )
)
station_info_json = eval(station_info.content) #将json字符串转为python对象
for railway in station_info_json['content']:
    uid = railway['line_uid']
    railway_json = requests.get(
        'https://map.baidu.com/?qt=bsl&tps=&newmap=1&uid=%s&c=%s' % (uid, city_code)
    )
    railway_json = eval(railway_json.content) #将json字符串转为python对象
    #......

# %%
trace_mercator = np.array(
        # 取出线路信息字典，以“|”划分后，取出第三部分信息，去掉末尾的“;”,获取BD-09MC坐标序列
        railway_json['content'][0]['geo'].split('|')[2][ : -1].split(','), 
        dtype=float
    ).reshape((-1, 2)) 
trace_coordinates = bd09_to_wgs84(mercator_to_bd09(trace_mercator))

# %%
railway_json['content'][0]['lineColor']
# Out:
# ''

# %%
import plotly.offline as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode


mapbox_access_token = "pk.eyJ1IjoibHVrYXNtYXJ0aW5lbGxpIiwiYSI6ImNpem85dmhwazAyajIyd284dGxhN2VxYnYifQ.HQCmyhEXZUTz3S98FMrVAQ"
layout = go.Layout(
    autosize=True,
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=39.9110666857, #广州市纬度
            lon= 116.4136103013 #广州市经度
        ),
        pitch=0,
        zoom=10
    ),
)

null = None #将json中的null定义为None
city_code = 131 #广州的城市编号
data = [] #绘制数据
marked = set()
for railway in station_info_json['content']:
    uid = railway['line_uid']
    if uid in marked: #由于线路包括了来回两个方向，需要排除已绘制线路的反向线路
        continue 
    railway_json = requests.get(
        'https://map.baidu.com/?qt=bsl&tps=&newmap=1&uid=%s&c=%s' % (uid, city_code)
    )
    railway_json = eval(railway_json.content) #将json字符串转为python对象
    trace_mercator = np.array(
        # 取出线路信息字典，以“|”划分后，取出第三部分信息，去掉末尾的“;”,获取BD-09MC坐标序列
        railway_json['content'][0]['geo'].split('|')[2][ : -1].split(','), 
        dtype=float
    ).reshape((-1, 2)) 
    trace_coordinates = bd09_to_wgs84(mercator_to_bd09(trace_mercator))
        
    plots = [] #站台BD-09MC坐标
    plots_name = [] #站台名称
    for plot in railway['stops']:
        plots.append([plot['x'], plot['y']])
        plots_name.append(plot['name'])
    plot_mercator = np.array(plots)
    plot_coordinates = bd09_to_wgs84(mercator_to_bd09(plot_mercator)) #站台经纬度
    
    if 'lineColor' in railway_json['content'][0]:
        color = railway_json['content'][0]['lineColor'] #利用json所给线路的颜色
    
    if not color:
        color = railway_json['content'][0]['line_color']
    
    data.extend([
        # 地铁路线
        go.Scattermapbox(
            lon=trace_coordinates[:, 0], #路线点经度
            lat=trace_coordinates[:, 1], #路线点纬度
            mode='lines',
            # 设置路线的参数
            line=go.scattermapbox.Line(
                width=2,
                color=color
            ),         
            name=railway['line_name'], #线路名称，显示在图例（legend）上
            legendgroup=railway['line_name']
        ),
        
        # 地铁站台
        go.Scattermapbox(
            lon=plot_coordinates[:, 0], #站台经度
            lat=plot_coordinates[:, 1], #站台纬度
            mode='markers',   
            text=plots_name,
            # 设置标记点的参数
            marker=go.scattermapbox.Marker(
                size=10,
                color=color
            ),
            name=railway['line_name'], #线路名称，显示在图例（legend）及鼠标悬浮在标记点时的路线名上
            legendgroup=railway['line_name'], #设置与路线同组，当隐藏该路线时隐藏标记点
            showlegend=False #不显示图例（legend)
        )
    ])
        
    marked.add(uid) #添加已绘制线路的uid
    marked.add(railway['pair_line_uid']) #添加已绘制线路反向线路的uid

fig = dict(data=data, layout=layout)
#py.iplot(fig) #直接显示地图
py.plot(fig, filename='北京地铁图.html') #生成html文件并打开
# Out:
# '北京地铁图.html'

# %%
import requests
import time

null = None #将json中的null定义为None
city_code = 131 #北京的城市编号
station_info = requests.get('http://map.baidu.com/?qt=bsi&c=%s&t=%s' % (
                    city_code, 
                    int(time.time() * 1000)
               )
)
station_info_json = eval(station_info.content) #将json字符串转为python对象

# %%
len(station_info_json)
# Out:
# 2

# %%
station_stations = {}
for station, lines in station_lines.items():
    stations = []
    for line in lines:
        stations += lines_stations[line]
    p = set(stations)
    p.remove(station)
    station_stations[station] = list(p)

# %%
station_stations
# Out:
# {'苹果园站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '古城站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '八角游乐园站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '四惠站'],
#  '八宝山站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八角游乐园站',
#   '四惠站'],
#  '玉泉路站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '五棵松站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '万寿路站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '公主坟站': ['东单站',
#   '惠新西街南口站',
#   '军事博物馆站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '复兴门站',
#   '永安里站',
#   '太阳宫站',
#   '玉泉路站',
#   '知春路站',
#   '建国门站',
#   '巴沟站',
#   '五棵松站',
#   '大望路站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '万寿路站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '苹果园站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '石榴庄站',
#   '潘家园站',
#   '天安门西站',
#   '角门西站',
#   '天安门东站',
#   '角门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '北土城站',
#   '呼家楼站',
#   '古城站',
#   '西土城站',
#   '长春桥站',
#   '木樨地站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '团结湖站',
#   '草桥站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站',
#   '四惠站'],
#  '军事博物馆站': ['东单站',
#   '国家图书馆站',
#   '丰台东大街站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '七里庄站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '六里桥站',
#   '苹果园站',
#   '白堆子站',
#   '丰台南路站',
#   '白石桥南站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '北京西站',
#   '郭公庄站',
#   '木樨地站',
#   '六里桥东站',
#   '丰台科技园站',
#   '科怡路站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '木樨地站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '南礼士路站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '复兴门站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '永安里站',
#   '崇文门站',
#   '玉泉路站',
#   '鼓楼大街站',
#   '西直门站',
#   '公主坟站',
#   '建国门站',
#   '东四十条站',
#   '五棵松站',
#   '大望路站',
#   '积水潭站',
#   '雍和宫站',
#   '车公庄站',
#   '万寿路站',
#   '北京站',
#   '长椿街站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '和平门站',
#   '东直门站',
#   '古城站',
#   '宣武门站',
#   '安定门站',
#   '木樨地站',
#   '阜成门站',
#   '前门站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '朝阳门站',
#   '四惠站'],
#  '西单站': ['东单站',
#   '国家图书馆站',
#   '军事博物馆站',
#   '海淀黄庄站',
#   '国贸站',
#   '魏公村站',
#   '安河桥北站',
#   '复兴门站',
#   '永安里站',
#   '北京大学东门站',
#   '中关村站',
#   '玉泉路站',
#   '人民大学站',
#   '菜市口站',
#   '公益西桥站',
#   '西苑站',
#   '公主坟站',
#   '建国门站',
#   '西直门站',
#   '北宫门站',
#   '五棵松站',
#   '大望路站',
#   '新街口站',
#   '万寿路站',
#   '灵境胡同站',
#   '平安里站',
#   '苹果园站',
#   '西四站',
#   '圆明园站',
#   '天安门西站',
#   '角门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '陶然亭站',
#   '古城站',
#   '宣武门站',
#   '马家堡站',
#   '木樨地站',
#   '八宝山站',
#   '八角游乐园站',
#   '动物园站',
#   '北京南站',
#   '四惠站'],
#  '天安门西站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '天安门东站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '王府井站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '东单站': ['惠新西街南口站',
#   '军事博物馆站',
#   '灯市口站',
#   '国贸站',
#   '立水桥南站',
#   '复兴门站',
#   '永安里站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '玉泉路站',
#   '立水桥站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '万寿路站',
#   '大屯路东站',
#   '张自忠路站',
#   '苹果园站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '天安门西站',
#   '和平里北街站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '天通苑北站',
#   '古城站',
#   '惠新西街北口站',
#   '木樨地站',
#   '北苑路北站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '建国门站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '崇文门站',
#   '玉泉路站',
#   '鼓楼大街站',
#   '西直门站',
#   '公主坟站',
#   '东四十条站',
#   '五棵松站',
#   '大望路站',
#   '积水潭站',
#   '雍和宫站',
#   '车公庄站',
#   '万寿路站',
#   '北京站',
#   '长椿街站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '和平门站',
#   '东直门站',
#   '古城站',
#   '宣武门站',
#   '安定门站',
#   '木樨地站',
#   '阜成门站',
#   '前门站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '朝阳门站',
#   '四惠站'],
#  '永安里站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '玉泉路站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '苹果园站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '古城站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '四惠站'],
#  '国贸站': ['东单站',
#   '惠新西街南口站',
#   '军事博物馆站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '莲花桥站',
#   '火器营站',
#   '复兴门站',
#   '永安里站',
#   '太阳宫站',
#   '玉泉路站',
#   '知春路站',
#   '公主坟站',
#   '建国门站',
#   '巴沟站',
#   '五棵松站',
#   '大望路站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '万寿路站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '苹果园站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '石榴庄站',
#   '潘家园站',
#   '天安门西站',
#   '角门西站',
#   '天安门东站',
#   '角门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '北土城站',
#   '呼家楼站',
#   '古城站',
#   '西土城站',
#   '长春桥站',
#   '木樨地站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '团结湖站',
#   '草桥站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站',
#   '四惠站'],
#  '大望路站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '蒲黄榆站',
#   '玉泉路站',
#   '七里庄站',
#   '金台路站',
#   '公主坟站',
#   '建国门站',
#   '张郭庄站',
#   '五棵松站',
#   '来广营站',
#   '阜通站',
#   '望京站',
#   '善各庄站',
#   '将台站',
#   '万寿路站',
#   '西局站',
#   '十里河站',
#   '苹果园站',
#   '朝阳公园站',
#   '景泰站',
#   '北工大西门站',
#   '天安门西站',
#   '天安门东站',
#   '枣营站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '园博园站',
#   '方庄站',
#   '古城站',
#   '大瓦窑站',
#   '东湖渠站',
#   '木樨地站',
#   '东风北桥站',
#   '郭庄子站',
#   '九龙山站',
#   '望京南站',
#   '永定门外站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '大井站',
#   '北京南站',
#   '四惠站'],
#  '四惠站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '土桥站',
#   '玉泉路站',
#   '临河里站',
#   '梨园站',
#   '八里桥站',
#   '果园站',
#   '高碑店站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '管庄站',
#   '苹果园站',
#   '通州北苑站',
#   '天安门西站',
#   '天安门东站',
#   '四惠东站',
#   '南礼士路站',
#   '王府井站',
#   '双桥站',
#   '古城站',
#   '传媒大学站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '九棵树站'],
#  '四惠东站': ['东单站',
#   '军事博物馆站',
#   '国贸站',
#   '复兴门站',
#   '永安里站',
#   '土桥站',
#   '玉泉路站',
#   '临河里站',
#   '梨园站',
#   '八里桥站',
#   '果园站',
#   '高碑店站',
#   '公主坟站',
#   '建国门站',
#   '五棵松站',
#   '大望路站',
#   '万寿路站',
#   '管庄站',
#   '苹果园站',
#   '通州北苑站',
#   '天安门西站',
#   '天安门东站',
#   '南礼士路站',
#   '王府井站',
#   '双桥站',
#   '古城站',
#   '传媒大学站',
#   '木樨地站',
#   '西单站',
#   '八宝山站',
#   '八角游乐园站',
#   '九棵树站',
#   '四惠站'],
#  '西直门站': ['国家图书馆站',
#   '北苑站',
#   '海淀黄庄站',
#   '芍药居站',
#   '魏公村站',
#   '安河桥北站',
#   '复兴门站',
#   '崇文门站',
#   '北京大学东门站',
#   '中关村站',
#   '人民大学站',
#   '菜市口站',
#   '立水桥站',
#   '公益西桥站',
#   '知春路站',
#   '鼓楼大街站',
#   '上地站',
#   '东四十条站',
#   '建国门站',
#   '西苑站',
#   '北宫门站',
#   '积水潭站',
#   '雍和宫站',
#   '新街口站',
#   '大钟寺站',
#   '北京站',
#   '灵境胡同站',
#   '平安里站',
#   '回龙观站',
#   '长椿街站',
#   '光熙门站',
#   '西四站',
#   '圆明园站',
#   '西二旗站',
#   '角门西站',
#   '五道口站',
#   '柳芳站',
#   '和平门站',
#   '陶然亭站',
#   '东直门站',
#   '宣武门站',
#   '安定门站',
#   '马家堡站',
#   '龙泽站',
#   '阜成门站',
#   '望京西站',
#   '前门站',
#   '霍营站',
#   '西单站',
#   '朝阳门站',
#   '动物园站',
#   '北京南站',
#   '车公庄站'],
#  '积水潭站': ['鼓楼大街站',
#   '北京站',
#   '西直门站',
#   '安定门站',
#   '东四十条站',
#   '建国门站',
#   '阜成门站',
#   '前门站',
#   '复兴门站',
#   '雍和宫站',
#   '崇文门站',
#   '和平门站',
#   '朝阳门站',
#   '东直门站',
#   '宣武门站',
#   '长椿街站',
#   '车公庄站'],
#  '鼓楼大街站': ['西小口站',
#   '南锣鼓巷站',
#   '复兴门站',
#   '崇文门站',
#   '永泰庄站',
#   '森林公园南门站',
#   '西直门站',
#   '东四十条站',
#   '建国门站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '积水潭站',
#   '雍和宫站',
#   '奥体中心站',
#   '朱辛庄站',
#   '北京站',
#   '平西府站',
#   '长椿街站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '和平门站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '东直门站',
#   '宣武门站',
#   '奥林匹克公园站',
#   '和义站',
#   '木樨园站',
#   '安定门站',
#   '阜成门站',
#   '什刹海站',
#   '前门站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站',
#   '朝阳门站',
#   '车公庄站'],
#  '安定门站': ['鼓楼大街站',
#   '北京站',
#   '西直门站',
#   '东四十条站',
#   '建国门站',
#   '阜成门站',
#   '前门站',
#   '复兴门站',
#   '积水潭站',
#   '雍和宫站',
#   '崇文门站',
#   '和平门站',
#   '朝阳门站',
#   '东直门站',
#   '宣武门站',
#   '长椿街站',
#   '车公庄站'],
#  '雍和宫站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '复兴门站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '鼓楼大街站',
#   '西直门站',
#   '东四十条站',
#   '建国门站',
#   '积水潭站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '北京站',
#   '大屯路东站',
#   '长椿街站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '和平门站',
#   '天通苑北站',
#   '东直门站',
#   '宣武门站',
#   '惠新西街北口站',
#   '安定门站',
#   '阜成门站',
#   '前门站',
#   '北苑路北站',
#   '朝阳门站',
#   '车公庄站'],
#  '东直门站': ['2号航站楼站',
#   '北苑站',
#   '芍药居站',
#   '复兴门站',
#   '崇文门站',
#   '立水桥站',
#   '上地站',
#   '知春路站',
#   '鼓楼大街站',
#   '西直门站',
#   '东四十条站',
#   '建国门站',
#   '积水潭站',
#   '雍和宫站',
#   '大钟寺站',
#   '北京站',
#   '回龙观站',
#   '长椿街站',
#   '光熙门站',
#   '西二旗站',
#   '五道口站',
#   '柳芳站',
#   '和平门站',
#   '3号航站楼站',
#   '宣武门站',
#   '安定门站',
#   '龙泽站',
#   '阜成门站',
#   '望京西站',
#   '前门站',
#   '霍营站',
#   '朝阳门站',
#   '三元桥站',
#   '车公庄站'],
#  '东四十条站': ['鼓楼大街站',
#   '北京站',
#   '西直门站',
#   '安定门站',
#   '建国门站',
#   '阜成门站',
#   '前门站',
#   '复兴门站',
#   '积水潭站',
#   '雍和宫站',
#   '崇文门站',
#   '和平门站',
#   '朝阳门站',
#   '东直门站',
#   '宣武门站',
#   '长椿街站',
#   '车公庄站'],
#  '朝阳门站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '复兴门站',
#   '常营站',
#   '崇文门站',
#   '东四站',
#   '金台路站',
#   '鼓楼大街站',
#   '西直门站',
#   '东四十条站',
#   '建国门站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '积水潭站',
#   '雍和宫站',
#   '北京站',
#   '平安里站',
#   '长椿街站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '和平门站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '东直门站',
#   '宣武门站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '安定门站',
#   '阜成门站',
#   '北运河东站',
#   '东大桥站',
#   '前门站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '北京站': ['鼓楼大街站',
#   '西直门站',
#   '安定门站',
#   '东四十条站',
#   '建国门站',
#   '阜成门站',
#   '前门站',
#   '复兴门站',
#   '积水潭站',
#   '雍和宫站',
#   '崇文门站',
#   '和平门站',
#   '朝阳门站',
#   '东直门站',
#   '宣武门站',
#   '长椿街站',
#   '车公庄站'],
#  '崇文门站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '复兴门站',
#   '蒲黄榆站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '鼓楼大街站',
#   '西直门站',
#   '东四十条站',
#   '建国门站',
#   '积水潭站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '北京站',
#   '大屯路东站',
#   '长椿街站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '和平门站',
#   '天通苑北站',
#   '东直门站',
#   '宣武门站',
#   '惠新西街北口站',
#   '安定门站',
#   '阜成门站',
#   '前门站',
#   '北苑路北站',
#   '朝阳门站',
#   '车公庄站'],
#  '前门站': ['鼓楼大街站',
#   '北京站',
#   '西直门站',
#   '安定门站',
#   '东四十条站',
#   '建国门站',
#   '阜成门站',
#   '复兴门站',
#   '积水潭站',
#   '雍和宫站',
#   '崇文门站',
#   '和平门站',
#   '朝阳门站',
#   '东直门站',
#   '宣武门站',
#   '长椿街站',
#   '车公庄站'],
#  '和平门站': ['鼓楼大街站',
#   '北京站',
#   '西直门站',
#   '安定门站',
#   '东四十条站',
#   '建国门站',
#   '阜成门站',
#   '前门站',
#   '复兴门站',
#   '积水潭站',
#   '雍和宫站',
#   '崇文门站',
#   '朝阳门站',
#   '东直门站',
#   '宣武门站',
#   '长椿街站',
#   '车公庄站'],
#  '宣武门站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '复兴门站',
#   '崇文门站',
#   '北京大学东门站',
#   '中关村站',
#   '人民大学站',
#   '菜市口站',
#   '公益西桥站',
#   '鼓楼大街站',
#   '西直门站',
#   '东四十条站',
#   '建国门站',
#   '西苑站',
#   '北宫门站',
#   '积水潭站',
#   '雍和宫站',
#   '新街口站',
#   '北京站',
#   '灵境胡同站',
#   '平安里站',
#   '长椿街站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '和平门站',
#   '陶然亭站',
#   '东直门站',
#   '安定门站',
#   '马家堡站',
#   '阜成门站',
#   '前门站',
#   '西单站',
#   '朝阳门站',
#   '动物园站',
#   '北京南站',
#   '车公庄站'],
#  '长椿街站': ['鼓楼大街站',
#   '北京站',
#   '西直门站',
#   '安定门站',
#   '东四十条站',
#   '建国门站',
#   '阜成门站',
#   '前门站',
#   '复兴门站',
#   '积水潭站',
#   '雍和宫站',
#   '崇文门站',
#   '和平门站',
#   '朝阳门站',
#   '东直门站',
#   '宣武门站',
#   '车公庄站'],
#  '阜成门站': ['鼓楼大街站',
#   '北京站',
#   '西直门站',
#   '安定门站',
#   '东四十条站',
#   '建国门站',
#   '前门站',
#   '复兴门站',
#   '积水潭站',
#   '雍和宫站',
#   '崇文门站',
#   '和平门站',
#   '朝阳门站',
#   '东直门站',
#   '宣武门站',
#   '长椿街站',
#   '车公庄站'],
#  '车公庄站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '复兴门站',
#   '常营站',
#   '崇文门站',
#   '东四站',
#   '金台路站',
#   '鼓楼大街站',
#   '西直门站',
#   '东四十条站',
#   '建国门站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '积水潭站',
#   '雍和宫站',
#   '北京站',
#   '平安里站',
#   '长椿街站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '和平门站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '东直门站',
#   '宣武门站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '安定门站',
#   '阜成门站',
#   '北运河东站',
#   '东大桥站',
#   '前门站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站'],
#  '安河桥北站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '北宫门站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '西苑站': ['国家图书馆站',
#   '温阳路站',
#   '北安河站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西直门站',
#   '屯佃站',
#   '稻香湖路站',
#   '北宫门站',
#   '新街口站',
#   '永丰南站',
#   '灵境胡同站',
#   '农大南路站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '马连洼站',
#   '角门西站',
#   '永丰站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '西北旺站',
#   '动物园站',
#   '北京南站'],
#  '圆明园站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '北京大学东门站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '中关村站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '海淀黄庄站': ['国家图书馆站',
#   '惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '魏公村站',
#   '安河桥北站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '知春路站',
#   '西苑站',
#   '西直门站',
#   '公主坟站',
#   '巴沟站',
#   '北宫门站',
#   '苏州街站',
#   '劲松站',
#   '新街口站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '灵境胡同站',
#   '知春里站',
#   '平安里站',
#   '双井站',
#   '泥洼站',
#   '十里河站',
#   '大红门站',
#   '西局站',
#   '西四站',
#   '六里桥站',
#   '西钓鱼台站',
#   '圆明园站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '安贞门站',
#   '角门东站',
#   '北土城站',
#   '陶然亭站',
#   '呼家楼站',
#   '宣武门站',
#   '三元桥站',
#   '西土城站',
#   '长春桥站',
#   '马家堡站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '西单站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '动物园站',
#   '北京南站'],
#  '人民大学站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '魏公村站': ['国家图书馆站',
#   '海淀黄庄站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '国家图书馆站': ['军事博物馆站',
#   '海淀黄庄站',
#   '丰台东大街站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '七里庄站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '六里桥站',
#   '西四站',
#   '白堆子站',
#   '圆明园站',
#   '丰台南路站',
#   '白石桥南站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '北京西站',
#   '马家堡站',
#   '六里桥东站',
#   '丰台科技园站',
#   '科怡路站',
#   '西单站',
#   '动物园站',
#   '北京南站',
#   '郭公庄站'],
#  '动物园站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '北京南站'],
#  '新街口站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '平安里站': ['国家图书馆站',
#   '金安桥站',
#   '海淀五路居站',
#   '海淀黄庄站',
#   '褡裢坡站',
#   '魏公村站',
#   '安河桥北站',
#   '南锣鼓巷站',
#   '常营站',
#   '北京大学东门站',
#   '东四站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '金台路站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '杨庄站',
#   '北宫门站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '新街口站',
#   '灵境胡同站',
#   '西四站',
#   '黄渠站',
#   '圆明园站',
#   '白石桥南站',
#   '通州北关站',
#   '角门西站',
#   '郝家府站',
#   '呼家楼站',
#   '陶然亭站',
#   '花园桥站',
#   '草房站',
#   '宣武门站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '马家堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西单站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '动物园站',
#   '北京南站',
#   '车公庄站'],
#  '西四站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '灵境胡同站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '菜市口站': ['国家图书馆站',
#   '广渠门外站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '双合站',
#   '南楼梓庄站',
#   '北京大学东门站',
#   '中关村站',
#   '人民大学站',
#   '公益西桥站',
#   '化工站',
#   '广渠门内站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '大郊亭站',
#   '百子湾站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '桥湾站',
#   '西四站',
#   '圆明园站',
#   '磁器口站',
#   '角门西站',
#   '湾子站',
#   '陶然亭站',
#   '达官营站',
#   '宣武门站',
#   '北京西站',
#   '马家堡站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '西单站',
#   '珠市口站',
#   '动物园站',
#   '北京南站'],
#  '陶然亭站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '北京南站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '蒲黄榆站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '七里庄站',
#   '金台路站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '张郭庄站',
#   '北宫门站',
#   '来广营站',
#   '阜通站',
#   '望京站',
#   '大望路站',
#   '新街口站',
#   '善各庄站',
#   '将台站',
#   '灵境胡同站',
#   '平安里站',
#   '西局站',
#   '十里河站',
#   '朝阳公园站',
#   '西四站',
#   '圆明园站',
#   '景泰站',
#   '北工大西门站',
#   '角门西站',
#   '枣营站',
#   '园博园站',
#   '陶然亭站',
#   '方庄站',
#   '宣武门站',
#   '大瓦窑站',
#   '东湖渠站',
#   '马家堡站',
#   '东风北桥站',
#   '郭庄子站',
#   '九龙山站',
#   '望京南站',
#   '永定门外站',
#   '西单站',
#   '动物园站',
#   '大井站'],
#  '马家堡站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '角门西站': ['国家图书馆站',
#   '惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '魏公村站',
#   '安河桥北站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '公益西桥站',
#   '知春路站',
#   '西苑站',
#   '西直门站',
#   '公主坟站',
#   '巴沟站',
#   '北宫门站',
#   '苏州街站',
#   '劲松站',
#   '新街口站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '灵境胡同站',
#   '知春里站',
#   '平安里站',
#   '双井站',
#   '泥洼站',
#   '十里河站',
#   '大红门站',
#   '西局站',
#   '西四站',
#   '六里桥站',
#   '西钓鱼台站',
#   '圆明园站',
#   '农业展览馆站',
#   '潘家园站',
#   '安贞门站',
#   '角门东站',
#   '北土城站',
#   '陶然亭站',
#   '呼家楼站',
#   '宣武门站',
#   '三元桥站',
#   '西土城站',
#   '长春桥站',
#   '马家堡站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '西单站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '动物园站',
#   '北京南站'],
#  '公益西桥站': ['国家图书馆站',
#   '海淀黄庄站',
#   '魏公村站',
#   '安河桥北站',
#   '北京大学东门站',
#   '中关村站',
#   '菜市口站',
#   '人民大学站',
#   '西苑站',
#   '西直门站',
#   '北宫门站',
#   '新街口站',
#   '灵境胡同站',
#   '平安里站',
#   '西四站',
#   '圆明园站',
#   '角门西站',
#   '陶然亭站',
#   '宣武门站',
#   '马家堡站',
#   '西单站',
#   '动物园站',
#   '北京南站'],
#  '宋家庄站': ['车道沟站',
#   '同济南路站',
#   '灯市口站',
#   '海淀黄庄站',
#   '莲花桥站',
#   '立水桥站',
#   '巴沟站',
#   '万源街站',
#   '苏州街站',
#   '劲松站',
#   '亮马桥站',
#   '大屯路东站',
#   '泥洼站',
#   '西局站',
#   '大红门站',
#   '西钓鱼台站',
#   '角门西站',
#   '北土城站',
#   '分钟寺站',
#   '团结湖站',
#   '石榴庄站',
#   '双井站',
#   '安贞门站',
#   '东单站',
#   '成寿寺站',
#   '亦庄火车站',
#   '荣京东街站',
#   '丰台站',
#   '国贸站',
#   '立水桥南站',
#   '天通苑南站',
#   '首经贸站',
#   '北新桥站',
#   '亦庄桥站',
#   '张自忠路站',
#   '十里河站',
#   '刘家窑站',
#   '农业展览馆站',
#   '亦庄文化园站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '草桥站',
#   '次渠南站',
#   '三元桥站',
#   '牡丹园站',
#   '旧宫站',
#   '蒲黄榆站',
#   '崇文门站',
#   '太阳宫站',
#   '经海路站',
#   '车站',
#   '知春路站',
#   '天坛东门站',
#   '知春里站',
#   '天通苑站',
#   '和平西桥站',
#   '次渠站',
#   '呼家楼站',
#   '西土城站',
#   '北苑路北站',
#   '慈寿寺站',
#   '肖村站',
#   '惠新西街南口站',
#   '芍药居站',
#   '火器营站',
#   '东四站',
#   '公主坟站',
#   '雍和宫站',
#   '荣昌东街站',
#   '六里桥站',
#   '潘家园站',
#   '角门东站',
#   '长春桥站',
#   '金台夕照站',
#   '小红门站',
#   '健德门站',
#   '纪家庙站'],
#  '刘家窑站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '蒲黄榆站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '七里庄站',
#   '立水桥站',
#   '金台路站',
#   '张郭庄站',
#   '来广营站',
#   '阜通站',
#   '望京站',
#   '大望路站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '将台站',
#   '大屯路东站',
#   '善各庄站',
#   '西局站',
#   '张自忠路站',
#   '十里河站',
#   '刘家窑站',
#   '朝阳公园站',
#   '天通苑站',
#   '和平西桥站',
#   '景泰站',
#   '磁器口站',
#   '和平里北街站',
#   '北工大西门站',
#   '枣营站',
#   '天通苑北站',
#   '园博园站',
#   '方庄站',
#   '大瓦窑站',
#   '惠新西街北口站',
#   '东湖渠站',
#   '东风北桥站',
#   '郭庄子站',
#   '九龙山站',
#   '望京南站',
#   '北苑路北站',
#   '永定门外站',
#   '大井站',
#   '北京南站'],
#  '天坛东门站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '磁器口站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '双合站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '南楼梓庄站',
#   '东四站',
#   '菜市口站',
#   '立水桥站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '桥湾站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '和平里北街站',
#   '天通苑北站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '惠新西街北口站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '北苑路北站',
#   '珠市口站',
#   '广渠门外站'],
#  '灯市口站': ['东单站',
#   '惠新西街南口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '东四站': ['东单站',
#   '惠新西街南口站',
#   '金安桥站',
#   '海淀五路居站',
#   '灯市口站',
#   '褡裢坡站',
#   '立水桥南站',
#   '南锣鼓巷站',
#   '常营站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '立水桥站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '平安里站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '通州北关站',
#   '白石桥南站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '郝家府站',
#   '天通苑北站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '惠新西街北口站',
#   '北运河东站',
#   '东大桥站',
#   '北苑路北站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '张自忠路站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '北新桥站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '和平里北街站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '和平西桥站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '惠新西街南口站': ['东单站',
#   '车道沟站',
#   '成寿寺站',
#   '灯市口站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '立水桥南站',
#   '火器营站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '太阳宫站',
#   '东四站',
#   '立水桥站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '雍和宫站',
#   '宋家庄站',
#   '劲松站',
#   '北新桥站',
#   '天坛东门站',
#   '亮马桥站',
#   '大屯路东站',
#   '首经贸站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '张自忠路站',
#   '十里河站',
#   '刘家窑站',
#   '大红门站',
#   '天通苑站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '天通苑北站',
#   '北土城站',
#   '呼家楼站',
#   '惠新西街北口站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '北苑路北站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '惠新西街北口站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '北苑路北站'],
#  '大屯路东站': ['东单站',
#   '惠新西街南口站',
#   '顺义站',
#   '后沙峪站',
#   '石门站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '清华东路西口站',
#   '国展站',
#   '望京站',
#   '俸伯站',
#   '雍和宫站',
#   '宋家庄站',
#   '崔各庄站',
#   '北新桥站',
#   '天坛东门站',
#   '关庄站',
#   '马泉营站',
#   '张自忠路站',
#   '六道口站',
#   '刘家窑站',
#   '孙河站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '南法信站',
#   '安立路站',
#   '天通苑北站',
#   '北沙滩站',
#   '花梨坎站',
#   '奥林匹克公园站',
#   '惠新西街北口站',
#   '望京西站',
#   '北苑路北站',
#   '望京东站'],
#  '北苑路北站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站'],
#  '立水桥南站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '立水桥站': ['东单站',
#   '惠新西街南口站',
#   '北苑站',
#   '灯市口站',
#   '芍药居站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '上地站',
#   '知春路站',
#   '西直门站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大钟寺站',
#   '大屯路东站',
#   '回龙观站',
#   '张自忠路站',
#   '刘家窑站',
#   '光熙门站',
#   '天通苑站',
#   '和平西桥站',
#   '西二旗站',
#   '磁器口站',
#   '和平里北街站',
#   '五道口站',
#   '柳芳站',
#   '天通苑北站',
#   '东直门站',
#   '惠新西街北口站',
#   '龙泽站',
#   '望京西站',
#   '霍营站',
#   '北苑路北站'],
#  '天通苑南站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '天通苑站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '天通苑北站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '天通苑北站': ['东单站',
#   '惠新西街南口站',
#   '灯市口站',
#   '立水桥南站',
#   '蒲黄榆站',
#   '崇文门站',
#   '天通苑南站',
#   '东四站',
#   '立水桥站',
#   '雍和宫站',
#   '宋家庄站',
#   '北新桥站',
#   '天坛东门站',
#   '大屯路东站',
#   '张自忠路站',
#   '刘家窑站',
#   '天通苑站',
#   '和平西桥站',
#   '磁器口站',
#   '和平里北街站',
#   '惠新西街北口站',
#   '北苑路北站'],
#  '金安桥站': ['海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '石厂站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '栗园庄站',
#   '四道桥站',
#   '平安里站',
#   '桥户营站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '小园站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '上岸站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '杨庄站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '黄渠站',
#   '车公庄站'],
#  '西黄村站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '廖公庄站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '田村站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '海淀五路居站': ['金安桥站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '慈寿寺站': ['惠新西街南口站',
#   '金安桥站',
#   '海淀五路居站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '褡裢坡站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '南锣鼓巷站',
#   '常营站',
#   '火器营站',
#   '太阳宫站',
#   '东四站',
#   '金台路站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '平安里站',
#   '双井站',
#   '泥洼站',
#   '十里河站',
#   '大红门站',
#   '西局站',
#   '纪家庙站',
#   '六里桥站',
#   '西钓鱼台站',
#   '通州北关站',
#   '白石桥南站',
#   '农业展览馆站',
#   '石榴庄站',
#   '潘家园站',
#   '安贞门站',
#   '角门西站',
#   '郝家府站',
#   '角门东站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北土城站',
#   '北运河西站',
#   '潞城站',
#   '三元桥站',
#   '十里堡站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '西黄村站',
#   '北海北站',
#   '朝阳门站',
#   '团结湖站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '花园桥站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '白石桥南站': ['国家图书馆站',
#   '金安桥站',
#   '海淀五路居站',
#   '军事博物馆站',
#   '褡裢坡站',
#   '丰台东大街站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '七里庄站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '六里桥站',
#   '白堆子站',
#   '通州北关站',
#   '丰台南路站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '北京西站',
#   '十里堡站',
#   '郭公庄站',
#   '六里桥东站',
#   '北运河东站',
#   '东大桥站',
#   '丰台科技园站',
#   '科怡路站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '车公庄西站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '北海北站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '南锣鼓巷站': ['金安桥站',
#   '海淀五路居站',
#   '西小口站',
#   '褡裢坡站',
#   '常营站',
#   '东四站',
#   '永泰庄站',
#   '森林公园南门站',
#   '金台路站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '平安里站',
#   '德茂站',
#   '通州北关站',
#   '白石桥南站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '郝家府站',
#   '天桥站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北土城站',
#   '安德里北街站',
#   '北运河西站',
#   '潞城站',
#   '奥林匹克公园站',
#   '和义站',
#   '木樨园站',
#   '十里堡站',
#   '什刹海站',
#   '北运河东站',
#   '东大桥站',
#   '回龙观东大街站',
#   '霍营站',
#   '东夏园站',
#   '五福堂站',
#   '永定门外站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '珠市口站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '东大桥站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '呼家楼站': ['惠新西街南口站',
#   '金安桥站',
#   '海淀五路居站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '褡裢坡站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '南锣鼓巷站',
#   '常营站',
#   '火器营站',
#   '太阳宫站',
#   '东四站',
#   '金台路站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '平安里站',
#   '双井站',
#   '泥洼站',
#   '十里河站',
#   '大红门站',
#   '西局站',
#   '纪家庙站',
#   '六里桥站',
#   '西钓鱼台站',
#   '通州北关站',
#   '白石桥南站',
#   '农业展览馆站',
#   '石榴庄站',
#   '潘家园站',
#   '安贞门站',
#   '角门西站',
#   '郝家府站',
#   '角门东站',
#   '草房站',
#   '花园桥站',
#   '北土城站',
#   '北运河西站',
#   '潞城站',
#   '三元桥站',
#   '十里堡站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '团结湖站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '金台路站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '蒲黄榆站',
#   '东四站',
#   '七里庄站',
#   '张郭庄站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '阜通站',
#   '大望路站',
#   '望京站',
#   '来广营站',
#   '善各庄站',
#   '将台站',
#   '平安里站',
#   '西局站',
#   '十里河站',
#   '朝阳公园站',
#   '通州北关站',
#   '白石桥南站',
#   '景泰站',
#   '北工大西门站',
#   '郝家府站',
#   '枣营站',
#   '北京南站',
#   '园博园站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '方庄站',
#   '北运河西站',
#   '潞城站',
#   '大瓦窑站',
#   '十里堡站',
#   '东湖渠站',
#   '东风北桥站',
#   '北运河东站',
#   '东大桥站',
#   '郭庄子站',
#   '九龙山站',
#   '望京南站',
#   '东夏园站',
#   '永定门外站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '大井站',
#   '黄渠站',
#   '车公庄站'],
#  '十里堡站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '青年路站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '褡裢坡站': ['金安桥站',
#   '海淀五路居站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '黄渠站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '车公庄站'],
#  '常营站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '草房站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '物资学院路站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '通州北关站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '北运河西站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '北运河东站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '郝家府站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '东夏园站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '潞城站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '潞城站': ['金安桥站',
#   '海淀五路居站',
#   '褡裢坡站',
#   '南锣鼓巷站',
#   '常营站',
#   '东四站',
#   '金台路站',
#   '廖公庄站',
#   '田村站',
#   '青年路站',
#   '车公庄西站',
#   '物资学院路站',
#   '平安里站',
#   '通州北关站',
#   '白石桥南站',
#   '郝家府站',
#   '呼家楼站',
#   '草房站',
#   '花园桥站',
#   '北运河西站',
#   '十里堡站',
#   '北运河东站',
#   '东大桥站',
#   '东夏园站',
#   '西黄村站',
#   '慈寿寺站',
#   '北海北站',
#   '朝阳门站',
#   '杨庄站',
#   '黄渠站',
#   '车公庄站'],
#  '北京西站': ['国家图书馆站',
#   '军事博物馆站',
#   '丰台东大街站',
#   '双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '七里庄站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '六里桥站',
#   '白堆子站',
#   '丰台南路站',
#   '白石桥南站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '焦化厂站',
#   '六里桥东站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '丰台科技园站',
#   '九龙山站',
#   '科怡路站',
#   '珠市口站',
#   '广渠门外站',
#   '郭公庄站'],
#  '湾子站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '达官营站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '广安门内站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '虎坊桥站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '珠市口站': ['西小口站',
#   '双合站',
#   '南锣鼓巷站',
#   '南楼梓庄站',
#   '永泰庄站',
#   '菜市口站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '化工站',
#   '广渠门内站',
#   '火箭万源站',
#   '海户屯站',
#   '大郊亭站',
#   '育新站',
#   '百子湾站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '桥湾站',
#   '德茂站',
#   '林萃桥站',
#   '磁器口站',
#   '育知路站',
#   '安华桥站',
#   '中国美术馆站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '湾子站',
#   '天桥站',
#   '北土城站',
#   '达官营站',
#   '安德里北街站',
#   '北京西站',
#   '奥林匹克公园站',
#   '和义站',
#   '木樨园站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '什刹海站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '广渠门外站'],
#  '桥湾站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '广渠门内站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '广渠门外站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站'],
#  '九龙山站': ['双合站',
#   '蒲黄榆站',
#   '南楼梓庄站',
#   '菜市口站',
#   '七里庄站',
#   '金台路站',
#   '化工站',
#   '广渠门内站',
#   '张郭庄站',
#   '大郊亭站',
#   '来广营站',
#   '阜通站',
#   '望京站',
#   '百子湾站',
#   '大望路站',
#   '善各庄站',
#   '将台站',
#   '西局站',
#   '桥湾站',
#   '十里河站',
#   '朝阳公园站',
#   '景泰站',
#   '磁器口站',
#   '北工大西门站',
#   '枣营站',
#   '北京南站',
#   '湾子站',
#   '园博园站',
#   '方庄站',
#   '达官营站',
#   '北京西站',
#   '大瓦窑站',
#   '东湖渠站',
#   '焦化厂站',
#   '东风北桥站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '郭庄子站',
#   '望京南站',
#   '永定门外站',
#   '珠市口站',
#   '大井站',
#   '广渠门外站'],
#  '大郊亭站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '百子湾站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '化工站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '南楼梓庄站': ['双合站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '欢乐谷景区站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '双合站': ['南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '焦化厂站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '焦化厂站': ['双合站',
#   '南楼梓庄站',
#   '菜市口站',
#   '化工站',
#   '广渠门内站',
#   '大郊亭站',
#   '百子湾站',
#   '桥湾站',
#   '磁器口站',
#   '湾子站',
#   '达官营站',
#   '北京西站',
#   '欢乐谷景区站',
#   '广安门内站',
#   '虎坊桥站',
#   '九龙山站',
#   '珠市口站',
#   '广渠门外站'],
#  '郭公庄站': ['国家图书馆站',
#   '军事博物馆站',
#   '大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '丰台东大街站',
#   '良乡大学城西站',
#   '稻田站',
#   '七里庄站',
#   '阎村东站',
#   '长阳站',
#   '六里桥站',
#   '白堆子站',
#   '丰台南路站',
#   '白石桥南站',
#   '北京西站',
#   '六里桥东站',
#   '丰台科技园站',
#   '良乡大学城站',
#   '科怡路站',
#   '广阳城站',
#   '良乡南关站',
#   '苏庄站'],
#  '丰台科技园站': ['国家图书馆站',
#   '军事博物馆站',
#   '丰台南路站',
#   '北京西站',
#   '六里桥东站',
#   '白堆子站',
#   '丰台东大街站',
#   '六里桥站',
#   '白石桥南站',
#   '科怡路站',
#   '七里庄站',
#   '郭公庄站'],
#  '科怡路站': ['国家图书馆站',
#   '军事博物馆站',
#   '丰台南路站',
#   '北京西站',
#   '六里桥东站',
#   '白堆子站',
#   '丰台东大街站',
#   '六里桥站',
#   '丰台科技园站',
#   '白石桥南站',
#   '七里庄站',
#   '郭公庄站'],
#  '丰台南路站': ['国家图书馆站',
#   '军事博物馆站',
#   '北京西站',
#   '六里桥东站',
#   '白堆子站',
#   '丰台东大街站',
#   '六里桥站',
#   '丰台科技园站',
#   '白石桥南站',
#   '科怡路站',
#   '七里庄站',
#   '郭公庄站'],
#  '丰台东大街站': ['国家图书馆站',
#   '军事博物馆站',
#   '丰台南路站',
#   '北京西站',
#   '六里桥东站',
#   '白堆子站',
#   '六里桥站',
#   '丰台科技园站',
#   '白石桥南站',
#   '科怡路站',
#   '七里庄站',
#   '郭公庄站'],
#  '七里庄站': ['国家图书馆站',
#   '军事博物馆站',
#   '丰台东大街站',
#   '蒲黄榆站',
#   '金台路站',
#   '张郭庄站',
#   '来广营站',
#   '阜通站',
#   '望京站',
#   '大望路站',
#   '善各庄站',
#   '将台站',
#   '西局站',
#   '六里桥站',
#   '十里河站',
#   '朝阳公园站',
#   '白堆子站',
#   '丰台南路站',
#   '白石桥南站',
#   '景泰站',
#   '北工大西门站',
#   '枣营站',
#   '园博园站',
#   '方庄站',
#   '北京西站',
#   '大瓦窑站',
#   '东湖渠站',
#   '六里桥东站',
#   '东风北桥站',
#   '丰台科技园站',
#   '郭庄子站',
#   '九龙山站',
#   '科怡路站',
#   '望京南站',
#   '永定门外站',
#   '大井站',
#   '北京南站',
#   '郭公庄站'],
#  '六里桥站': ['国家图书馆站',
#   '惠新西街南口站',
#   '军事博物馆站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '丰台东大街站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '七里庄站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '西钓鱼台站',
#   '白堆子站',
#   '丰台南路站',
#   '白石桥南站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '北京西站',
#   '西土城站',
#   '长春桥站',
#   '六里桥东站',
#   '金台夕照站',
#   '丰台科技园站',
#   '科怡路站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站',
#   '郭公庄站'],
#  '六里桥东站': ['国家图书馆站',
#   '军事博物馆站',
#   '丰台南路站',
#   '北京西站',
#   '白堆子站',
#   '丰台东大街站',
#   '六里桥站',
#   '丰台科技园站',
#   '白石桥南站',
#   '科怡路站',
#   '七里庄站',
#   '郭公庄站'],
#  '白堆子站': ['国家图书馆站',
#   '军事博物馆站',
#   '丰台南路站',
#   '北京西站',
#   '六里桥东站',
#   '丰台东大街站',
#   '六里桥站',
#   '丰台科技园站',
#   '白石桥南站',
#   '科怡路站',
#   '七里庄站',
#   '郭公庄站'],
#  '巴沟站': ['惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '知春路站',
#   '公主坟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '苏州街站': ['惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '知春里站': ['惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '知春路站': ['惠新西街南口站',
#   '北苑站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '立水桥站',
#   '上地站',
#   '西直门站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '大钟寺站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '回龙观站',
#   '光熙门站',
#   '农业展览馆站',
#   '西二旗站',
#   '潘家园站',
#   '角门西站',
#   '五道口站',
#   '柳芳站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '东直门站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '龙泽站',
#   '望京西站',
#   '霍营站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '西土城站': ['惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '长春桥站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '牡丹园站': ['惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '健德门站': ['惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '北土城站': ['惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '西小口站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '南锣鼓巷站',
#   '太阳宫站',
#   '永泰庄站',
#   '森林公园南门站',
#   '知春路站',
#   '鼓楼大街站',
#   '公主坟站',
#   '火箭万源站',
#   '巴沟站',
#   '海户屯站',
#   '育新站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '奥体中心站',
#   '亮马桥站',
#   '朱辛庄站',
#   '平西府站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '德茂站',
#   '农业展览馆站',
#   '林萃桥站',
#   '潘家园站',
#   '育知路站',
#   '角门西站',
#   '安华桥站',
#   '中国美术馆站',
#   '瀛海站',
#   '角门东站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '呼家楼站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '健德门站',
#   '分钟寺站',
#   '五福堂站',
#   '永定门外站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '珠市口站',
#   '纪家庙站',
#   '安贞门站',
#   '三元桥站'],
#  '安贞门站': ['惠新西街南口站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '芍药居站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '知春路站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '农业展览馆站',
#   '潘家园站',
#   '角门西站',
#   '角门东站',
#   '北土城站',
#   '呼家楼站',
#   '西土城站',
#   '长春桥站',
#   '金台夕照站',
#   '健德门站',
#   '分钟寺站',
#   '草桥站',
#   '团结湖站',
#   '石榴庄站',
#   '慈寿寺站',
#   '纪家庙站',
#   '三元桥站'],
#  '芍药居站': ['惠新西街南口站',
#   '北苑站',
#   '车道沟站',
#   '成寿寺站',
#   '海淀黄庄站',
#   '牡丹园站',
#   '丰台站',
#   '国贸站',
#   '莲花桥站',
#   '火器营站',
#   '太阳宫站',
#   '立水桥站',
#   '上地站',
#   '知春路站',
#   '西直门站',
#   '公主坟站',
#   '巴沟站',
#   '苏州街站',
#   '劲松站',
#   '宋家庄站',
#   '首经贸站',
#   '亮马桥站',
#   '大钟寺站',
#   '知春里站',
#   '双井站',
#   '泥洼站',
#   '西局站',
#   '十里河站',
#   '大红门站',
#   '六里桥站',
#   '西钓鱼台站',
#   '回龙观站',
#   '光熙门站',
#   '农业展览馆站',
#   '西二旗站',
# ...
#   '孙河站',
#   '南法信站',
#   '安立路站',
#   '北沙滩站',
#   '奥林匹克公园站',
#   '花梨坎站',
#   '望京西站',
#   '望京东站'],
#  '农大南路站': ['温阳路站',
#   '西苑站',
#   '屯佃站',
#   '稻香湖路站',
#   '北安河站',
#   '马连洼站',
#   '永丰南站',
#   '永丰站',
#   '西北旺站'],
#  '马连洼站': ['温阳路站',
#   '西苑站',
#   '屯佃站',
#   '稻香湖路站',
#   '北安河站',
#   '永丰南站',
#   '永丰站',
#   '农大南路站',
#   '西北旺站'],
#  '西北旺站': ['温阳路站',
#   '西苑站',
#   '屯佃站',
#   '稻香湖路站',
#   '北安河站',
#   '马连洼站',
#   '永丰南站',
#   '永丰站',
#   '农大南路站'],
#  '永丰南站': ['温阳路站',
#   '西苑站',
#   '屯佃站',
#   '稻香湖路站',
#   '北安河站',
#   '马连洼站',
#   '永丰站',
#   '农大南路站',
#   '西北旺站'],
#  '永丰站': ['温阳路站',
#   '西苑站',
#   '屯佃站',
#   '稻香湖路站',
#   '北安河站',
#   '马连洼站',
#   '永丰南站',
#   '农大南路站',
#   '西北旺站'],
#  '屯佃站': ['温阳路站',
#   '西苑站',
#   '稻香湖路站',
#   '北安河站',
#   '马连洼站',
#   '永丰南站',
#   '永丰站',
#   '农大南路站',
#   '西北旺站'],
#  '稻香湖路站': ['温阳路站',
#   '西苑站',
#   '屯佃站',
#   '北安河站',
#   '马连洼站',
#   '永丰南站',
#   '永丰站',
#   '农大南路站',
#   '西北旺站'],
#  '温阳路站': ['西苑站',
#   '屯佃站',
#   '稻香湖路站',
#   '北安河站',
#   '马连洼站',
#   '永丰南站',
#   '永丰站',
#   '农大南路站',
#   '西北旺站'],
#  '北安河站': ['温阳路站',
#   '西苑站',
#   '屯佃站',
#   '稻香湖路站',
#   '马连洼站',
#   '永丰南站',
#   '永丰站',
#   '农大南路站',
#   '西北旺站'],
#  '高碑店站': ['通州北苑站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '管庄站',
#   '双桥站',
#   '临河里站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '传媒大学站': ['高碑店站',
#   '通州北苑站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '管庄站',
#   '双桥站',
#   '临河里站',
#   '九棵树站',
#   '四惠站'],
#  '双桥站': ['高碑店站',
#   '通州北苑站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '管庄站',
#   '临河里站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '管庄站': ['高碑店站',
#   '通州北苑站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '双桥站',
#   '临河里站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '八里桥站': ['高碑店站',
#   '通州北苑站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '管庄站',
#   '双桥站',
#   '临河里站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '通州北苑站': ['高碑店站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '管庄站',
#   '双桥站',
#   '临河里站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '果园站': ['高碑店站',
#   '通州北苑站',
#   '八里桥站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '管庄站',
#   '双桥站',
#   '临河里站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '九棵树站': ['高碑店站',
#   '通州北苑站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '管庄站',
#   '双桥站',
#   '临河里站',
#   '传媒大学站',
#   '四惠站'],
#  '梨园站': ['高碑店站',
#   '通州北苑站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '管庄站',
#   '双桥站',
#   '临河里站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '临河里站': ['高碑店站',
#   '通州北苑站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '土桥站',
#   '梨园站',
#   '管庄站',
#   '双桥站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '土桥站': ['高碑店站',
#   '通州北苑站',
#   '八里桥站',
#   '果园站',
#   '四惠东站',
#   '梨园站',
#   '管庄站',
#   '双桥站',
#   '临河里站',
#   '九棵树站',
#   '传媒大学站',
#   '四惠站'],
#  '昌平西山口站': ['沙河高教园站',
#   '生命科学园站',
#   '昌平站',
#   '西二旗站',
#   '沙河站',
#   '南邵站',
#   '十三陵景区站',
#   '北邵洼站',
#   '巩华城站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '十三陵景区站': ['沙河高教园站',
#   '生命科学园站',
#   '昌平站',
#   '西二旗站',
#   '沙河站',
#   '南邵站',
#   '昌平西山口站',
#   '北邵洼站',
#   '巩华城站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '昌平站': ['沙河高教园站',
#   '生命科学园站',
#   '西二旗站',
#   '沙河站',
#   '南邵站',
#   '昌平西山口站',
#   '十三陵景区站',
#   '北邵洼站',
#   '巩华城站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '昌平东关站': ['沙河高教园站',
#   '生命科学园站',
#   '昌平站',
#   '西二旗站',
#   '沙河站',
#   '南邵站',
#   '昌平西山口站',
#   '十三陵景区站',
#   '北邵洼站',
#   '巩华城站',
#   '朱辛庄站'],
#  '北邵洼站': ['沙河高教园站',
#   '生命科学园站',
#   '昌平站',
#   '西二旗站',
#   '沙河站',
#   '南邵站',
#   '昌平西山口站',
#   '十三陵景区站',
#   '巩华城站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '南邵站': ['沙河高教园站',
#   '生命科学园站',
#   '昌平站',
#   '西二旗站',
#   '沙河站',
#   '昌平西山口站',
#   '十三陵景区站',
#   '北邵洼站',
#   '巩华城站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '沙河高教园站': ['生命科学园站',
#   '昌平站',
#   '西二旗站',
#   '沙河站',
#   '南邵站',
#   '昌平西山口站',
#   '十三陵景区站',
#   '北邵洼站',
#   '巩华城站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '沙河站': ['沙河高教园站',
#   '生命科学园站',
#   '昌平站',
#   '西二旗站',
#   '南邵站',
#   '昌平西山口站',
#   '十三陵景区站',
#   '北邵洼站',
#   '巩华城站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '巩华城站': ['沙河高教园站',
#   '生命科学园站',
#   '昌平站',
#   '西二旗站',
#   '沙河站',
#   '南邵站',
#   '昌平西山口站',
#   '十三陵景区站',
#   '北邵洼站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '朱辛庄站': ['西小口站',
#   '南邵站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '昌平站',
#   '火箭万源站',
#   '海户屯站',
#   '沙河站',
#   '育新站',
#   '北邵洼站',
#   '巩华城站',
#   '奥体中心站',
#   '昌平东关站',
#   '平西府站',
#   '沙河高教园站',
#   '生命科学园站',
#   '德茂站',
#   '西二旗站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '昌平西山口站',
#   '瀛海站',
#   '东高地站',
#   '十三陵景区站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '生命科学园站': ['沙河高教园站',
#   '昌平站',
#   '西二旗站',
#   '沙河站',
#   '南邵站',
#   '昌平西山口站',
#   '十三陵景区站',
#   '北邵洼站',
#   '巩华城站',
#   '昌平东关站',
#   '朱辛庄站'],
#  '亦庄火车站': ['同济南路站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '车站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '肖村站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站'],
#  '小红门站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '旧宫站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '亦庄桥站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '次渠南站',
#   '肖村站'],
#  '亦庄文化园站': ['同济南路站',
#   '亦庄火车站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '万源街站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '荣京东街站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '荣昌东街站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '同济南路站': ['亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '经海路站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '次渠南站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '次渠站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '肖村站'],
#  '次渠站': ['同济南路站',
#   '亦庄火车站',
#   '亦庄文化园站',
#   '荣京东街站',
#   '旧宫站',
#   '万源街站',
#   '小红门站',
#   '宋家庄站',
#   '经海路站',
#   '车站',
#   '荣昌东街站',
#   '亦庄桥站',
#   '次渠南站',
#   '肖村站'],
#  '大葆台站': ['良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '良乡大学城站',
#   '阎村东站',
#   '稻田站',
#   '广阳城站',
#   '良乡南关站',
#   '长阳站',
#   '苏庄站',
#   '郭公庄站'],
#  '稻田站': ['大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '良乡大学城站',
#   '阎村东站',
#   '广阳城站',
#   '良乡南关站',
#   '长阳站',
#   '苏庄站',
#   '郭公庄站'],
#  '长阳站': ['大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '良乡大学城站',
#   '阎村东站',
#   '稻田站',
#   '广阳城站',
#   '良乡南关站',
#   '苏庄站',
#   '郭公庄站'],
#  '篱笆房站': ['大葆台站',
#   '良乡大学城北站',
#   '良乡大学城西站',
#   '良乡大学城站',
#   '阎村东站',
#   '稻田站',
#   '广阳城站',
#   '良乡南关站',
#   '长阳站',
#   '苏庄站',
#   '郭公庄站'],
#  '广阳城站': ['大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '良乡大学城站',
#   '阎村东站',
#   '稻田站',
#   '良乡南关站',
#   '长阳站',
#   '苏庄站',
#   '郭公庄站'],
#  '良乡大学城北站': ['大葆台站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '良乡大学城站',
#   '阎村东站',
#   '稻田站',
#   '广阳城站',
#   '良乡南关站',
#   '长阳站',
#   '苏庄站',
#   '郭公庄站'],
#  '良乡大学城站': ['大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '阎村东站',
#   '稻田站',
#   '广阳城站',
#   '良乡南关站',
#   '长阳站',
#   '苏庄站',
#   '郭公庄站'],
#  '良乡大学城西站': ['大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城站',
#   '阎村东站',
#   '稻田站',
#   '广阳城站',
#   '良乡南关站',
#   '长阳站',
#   '苏庄站',
#   '郭公庄站'],
#  '良乡南关站': ['大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '良乡大学城站',
#   '阎村东站',
#   '稻田站',
#   '广阳城站',
#   '长阳站',
#   '苏庄站',
#   '郭公庄站'],
#  '苏庄站': ['大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '良乡大学城站',
#   '阎村东站',
#   '稻田站',
#   '广阳城站',
#   '良乡南关站',
#   '长阳站',
#   '郭公庄站'],
#  '阎村东站': ['大葆台站',
#   '良乡大学城北站',
#   '篱笆房站',
#   '良乡大学城西站',
#   '稻田站',
#   '阎村站',
#   '饶乐府站',
#   '星城站',
#   '长阳站',
#   '大石河东站',
#   '燕山站',
#   '马各庄站',
#   '房山城关站',
#   '紫草坞站',
#   '良乡大学城站',
#   '广阳城站',
#   '良乡南关站',
#   '苏庄站',
#   '郭公庄站'],
#  '四道桥站': ['金安桥站', '石厂站', '栗园庄站', '小园站', '上岸站', '桥户营站'],
#  '桥户营站': ['金安桥站', '石厂站', '栗园庄站', '小园站', '四道桥站', '上岸站'],
#  '上岸站': ['金安桥站', '石厂站', '栗园庄站', '小园站', '四道桥站', '桥户营站'],
#  '栗园庄站': ['金安桥站', '石厂站', '小园站', '四道桥站', '上岸站', '桥户营站'],
#  '小园站': ['金安桥站', '石厂站', '栗园庄站', '四道桥站', '上岸站', '桥户营站'],
#  '石厂站': ['金安桥站', '栗园庄站', '小园站', '四道桥站', '上岸站', '桥户营站'],
#  '燕山站': ['饶乐府站', '紫草坞站', '马各庄站', '阎村东站', '星城站', '阎村站', '大石河东站', '房山城关站'],
#  '房山城关站': ['燕山站', '饶乐府站', '紫草坞站', '马各庄站', '阎村东站', '星城站', '阎村站', '大石河东站'],
#  '饶乐府站': ['燕山站', '紫草坞站', '马各庄站', '阎村东站', '星城站', '阎村站', '大石河东站', '房山城关站'],
#  '马各庄站': ['燕山站', '饶乐府站', '紫草坞站', '阎村东站', '星城站', '阎村站', '大石河东站', '房山城关站'],
#  '大石河东站': ['燕山站', '饶乐府站', '紫草坞站', '马各庄站', '阎村东站', '星城站', '阎村站', '房山城关站'],
#  '星城站': ['燕山站', '饶乐府站', '紫草坞站', '马各庄站', '阎村东站', '阎村站', '大石河东站', '房山城关站'],
#  '阎村站': ['燕山站', '饶乐府站', '紫草坞站', '马各庄站', '阎村东站', '星城站', '大石河东站', '房山城关站'],
#  '紫草坞站': ['燕山站', '饶乐府站', '马各庄站', '阎村东站', '星城站', '阎村站', '大石河东站', '房山城关站'],
#  '育知路站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '平西府站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '回龙观东大街站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '育新站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '西小口站': ['南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '永泰庄站': ['西小口站',
#   '南锣鼓巷站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '林萃桥站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '森林公园南门站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '奥体中心站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '安华桥站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '安德里北街站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '什刹海站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '中国美术馆站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '瀛海站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '德茂站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '五福堂站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '永定门外站',
#   '珠市口站'],
#  '火箭万源站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '东高地站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '和义站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '大红门南站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '海户屯站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '木樨园站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '天桥站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '天桥站': ['西小口站',
#   '南锣鼓巷站',
#   '永泰庄站',
#   '森林公园南门站',
#   '鼓楼大街站',
#   '火箭万源站',
#   '海户屯站',
#   '育新站',
#   '奥体中心站',
#   '朱辛庄站',
#   '平西府站',
#   '德茂站',
#   '林萃桥站',
#   '育知路站',
#   '中国美术馆站',
#   '安华桥站',
#   '瀛海站',
#   '东高地站',
#   '大红门南站',
#   '北土城站',
#   '安德里北街站',
#   '和义站',
#   '奥林匹克公园站',
#   '木樨园站',
#   '什刹海站',
#   '回龙观东大街站',
#   '霍营站',
#   '五福堂站',
#   '永定门外站',
#   '珠市口站'],
#  '3号航站楼站': ['东直门站', '2号航站楼站', '三元桥站'],
#  '2号航站楼站': ['3号航站楼站', '东直门站', '三元桥站']}

# %%
from collections import defaultdict
station_connection = defaultdict(list)

# %%
station_connection.update(station_stations)

# %%
def search(start, destination, connection_grpah):
    pathes = [[start]]
    
    visitied = set()
    
    while pathes: # if we find existing pathes
        path = pathes.pop(0)
        froninter = path[-1]
        
        if froninter in visitied: continue
            
        successors = connection_grpah[froninter]
        
        for city in successors:
            if city in path: continue  # eliminate loop
                
            new_path = path + [city]
            
            pathes.append(new_path)
            #print(new_path)
            
            if city == destination: return new_path
        
        visitied.add(froninter)
        
        #pathes = sort_candidate(pathes) # 我们可以加一个排序函数 对我们的搜索策略进行控制

# %%
print(search('亦庄火车站','苏庄站',station_connection))
# Out:
# ['亦庄火车站', '宋家庄站', '六里桥站', '郭公庄站', '苏庄站']

# %%
print(search('北沙滩站','亦庄火车站',station_connection))
# Out:
# ['北沙滩站', '大屯路东站', '宋家庄站', '亦庄火车站']

# %%
print(search('奥体中心站','天安门站',station_connection))
# Out:
# None

# %% [markdown]
# ##### 3. Build the search agent
#
# > Build the search agent based on the graph we build.
#
# for example, when you run:
#
# ```python
# >>> search('奥体中心', '天安门')
# ```
# you need get the result:
#
# 奥体中心-> A -> B -> C -> ... -> 天安门

# %% [markdown]
# ## （Optional）Create different policies for transfer system.

# %% [markdown]
# 以下部门为可选部分，请酌情完成。 并不要求全部同学完成。

# %% [markdown]
# As much as you can to use the already implemented search agent. You just need to define the **is_goal()**, **get_successor()**, **strategy()** three functions.
#
# > a.	Define different policies for transfer system.
#
# > b.	Such as Shortest Path Priority（路程最短优先）, Minimum Transfer Priority(最少换乘优先), Comprehensive Priority(综合优先)
#
# > c.	Implement Continuous transfer. Based on the Agent you implemented, please add this feature: Besides the @param start and @param destination two stations, add some more stations, we called @param by_way, it means, our path should from the start and end, but also include the  @param by_way stations.
#
# e.g
# ```
# 1. Input:  start=A,  destination=B, by_way=[C]
#     Output: [A, … .., C, …. B]
# 2. Input: start=A, destination=B, by_way=[C, D, E]
#     Output: [A … C … E … D … B]
#     # based on your policy, the E station could be reached firstly.
# ![image.png](attachment:image.png)
# ```

# %% [markdown]
# ##### 5.	Test your result with commercial applications.
#
# 将你的结果和高德地图或者百度地图进行比较，如果有不同，请分析原因

# %% [markdown]
# 恭喜，完成本次课程，你对常用的人工智能方法以及有一定的了解了。基于规则的，基于概率模型的，基于搜索的，基于机器学习的。 可以说，我们现在通常见到的方法都能够归属到这几类方法中。 这就是**人工智能**，并没有很难是吧？ 继续加油！

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562415163815&di=4b29a2a863a8285212033760f288ed7a&imgtype=0&src=http%3A%2F%2F5b0988e595225.cdn.sohucs.com%2Fimages%2F20180710%2F8704194a1d7f46a383ddc29d40c9bca5.jpeg)
